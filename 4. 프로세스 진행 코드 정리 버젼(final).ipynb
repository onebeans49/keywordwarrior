# %% [markdown]
# # 구글 플레이스토어 리뷰 크롤링
# ### df_reviews 변수에 크롤링한 데이터 저장
# ##### Temp 경로에 저장  -> 디렉토리에 크롤링한 파일을 저장했다가 추후 불러오므로 주의

# %%
from google_play_scraper import reviews, search
import pandas as pd
from google_play_scraper import Sort

def scrap_reviews(app_name):
    """
    주어진 앱 이름으로부터 리뷰를 수집하고, 스코어와 컨텐트만 남기는 함수입니다.
    매개변수:
    app_name (str): 리뷰를 수집할 앱의 이름입니다.
    반환값:
    df_reviews (DataFrame): 수집된 리뷰의 스코어와 컨텐트를 담은 데이터프레임입니다.
    """
    # 해당 앱의 검색 결과를 가져옵니다.
    search_results = search(app_name, lang="ko", country="kr", n_hits=1)
    app_id = search_results[0]['appId']

    # 앱 ID를 사용하여 한국어 리뷰를 가져옵니다.
    reviews_list = []
    continuation_token = None
    while True: # 모든 리뷰를 가져올 때까지 반복합니다.
        result, continuation_token = reviews(
            app_id,
            count=50, # 한 번에 가져올 리뷰의 수입니다.
            lang='ko',
            country='kr',
            sort=Sort.NEWEST,
            continuation_token=continuation_token
        )
        # 만약 더 이상 리뷰가 없다면 반복문을 종료합니다.
        if not result:
            break
        reviews_list.extend(result)

    # 가져온 리뷰가 없다면 빈 데이터프레임을 반환합니다.
    if len(reviews_list) == 0:
        return pd.DataFrame()

    # 가져온 리뷰를 DataFrame으로 변환합니다.
    df_reviews = pd.DataFrame(reviews_list)

    # 스코어와 컨텐트, 추천수만 남깁니다.
    df_reviews = df_reviews[['score', 'content', 'thumbsUpCount']]

    # 각 앱에 대해 수집된 리뷰 수를 출력합니다.
    print(f"Collected {len(reviews_list)} reviews for '{app_name}'")

    return df_reviews

app_name = input('분석할 앱을 지정해주세요 : ') 
df_reviews = scrap_reviews(app_name)
df_reviews.to_csv('C:/Temp/df_reviews.csv')
# Out:
# 분석할 앱을 지정해주세요 : 아키에이지 워
# Collected 4353 reviews for '아키에이지 워'

# %% [raw]
# ### 데이터를 로드 한 직후 num컬럼 추가합니다
# #### 또한 num컬럼을 앞으로 옮깁니다

# %%
df_reviews['num'] = df_reviews.index

# 'num' 컬럼을 맨 앞으로 옮깁니다.
cols = df_reviews.columns.tolist()
cols = [cols[-1]] + cols[:-1]
df_reviews = df_reviews[cols]

print(df_reviews.head())
# Out:
#    num  score                                            content  \
# 0    0      4                                          일단해보시길...
# 1    1      3                                              재밌어요~
# 2    2      3  재미는 있는데...돈 많이 써야되는건 타 게임들 비슷 한데... 뭔놈에 게임이 베터...
# 3    3      4                                          좋아요 재미있어요
# 4    4      5                                              재미있어요
#
#    thumbsUpCount
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %% [markdown]
# ### num 컬럼이 생성된 이 데이터 프레임을 다시 저장합니다

# %%
df_reviews.to_csv('C:/Temp/df_reviews_num.csv')

# %% [markdown]
# ### 키워드 선언¶
# #### 키워드를 추가합니다(긍/부정에 나타날 키워드)

# %%
# 게임 리뷰에서 자주 사용되는 키워드와 그 변형어를 그룹화한 리스트
# 예를 들면, '렉'은 '랙'이나 '잔렉'이라는 단어로도 사용될 수 있습니다.

keywords_grouped = [
    ['렉', '랙', '잔렉'],
    ['업데이트', '업뎃'],
    ['패치'],
    ['팅', '팅김', '튕김'],
    ['로딩'],
    ['rpg', '알피지'],
    ['섭종'],
    ['스토리'],
    ['캐릭터', '케릭', '캐릭'],
    ['데미지', '뎀', '뎀지', '퍼뎀', '추뎀'],
    ['딜', '딜량'],
    ['콘셉트', '컨셉', '콘셉'],
    ['BGM', 'bgm', '브금', '배경음악'],
    ['노래', '음악'],
    ['의상', '코디', '아바타', '옷', '코스튬', '스킨'],
    ['커스터마이징', '커마'],
    ['자유도'],
    ['컨텐츠', '콘텐츠'],
    ['플레티넘', '플래', '플레'],
    ['챌린저', '챌린져', '챌', '첼린져'],
    ['다이아몬드', '다이아', '다야'],
    ['아처', '아쳐'],
    ['서포터', '서폿'],
    ['갓겜'],
    ['레전드', '래전드'],
    ['가챠', '가차', '갸챠', '갸차'],
    ['무과금'],
    ['과금', '현질'],
    ['일러스트', '일러'],
    ['튜토리얼', '듀토리얼', '튜토'],
    ['유튜브', '유툽', '유튭', '유투브'],
    ['광고'],
    ['그래픽', '글픽', '화질'],
    ['밸런스', '벨붕', '벨런스', '밸붕'],
    ['조작감', '조작', '컨트롤'],
    ['ai', 'AI'],
    ['버그', '오류', '에러'],
    ['데이터'],
    ['와이파이'],
    ['난이도', '하드코어', '어렵', '쉽'],
    ['억까', '어까'],
    ['노잼', '누잼', '개노잼'],
    ['스릴', '박진감'],
    ['짭퉁', '짝퉁', '짭', '카피', '표절'],
    ['꿀잼', '졸잼', '꾸르잼', '개꾸르잼'],
    ['트롤', '비매너', '개트롤'],
    ['리듬', '박자'],
    ['랭크'],
    ['미션'],
    ['중독성'],
    ['루비', '보석', '유료재화', '크리스탈'],
    ['시스템', '구조'],
    ['자동', '오토'],
    ['타격감', '손맛'],
    ['업글', '업그레이드'],
    ['핵', '핵쟁이', '핵유저', '에디터', '중국'],
    ['편의성'],
    ['불친절', '가이드'],
    ['최적화', '발열'],
    ['전술'],
    ['운영'],
    ['소통'],
    ['현실감'],
    ['네트워크', '인터넷'],
    ['킬링타임']
]
# 위에서 그룹화한 키워드들 중 각 그룹의 대표 키워드(첫 번째 키워드)만을 추출하여 저장할 리스트
keywords = []
# 각 그룹의 대표 키워드만 추출하는 반복문
for item in keywords_grouped:
    # item이 리스트인 경우 (즉, 유사어가 있는 경우)
    if isinstance(item, list):
        # 대표 키워드만 keywords 리스트에 추가
        keywords.append(item[0])
         # item이 단일 문자열인 경우 (즉, 유사어가 없는 경우)
    else:
        # 해당 키워드를 그대로 keywords 리스트에 추가
        keywords.append(item)

# %% [markdown]
# ### 세부평점 도출
# ##### keyword_scores 변수에 각 키워드별 스코어를 딕셔너리 형태로 저장

# %%
# 딕셔너리를 사용하여 키워드별 평균 점수 저장
keyword_scores = {}  # 키워드별 평균 점수를 저장할 딕셔너리

# 모든 키워드에 대하여 반복
for keyword in keywords:
    # 리뷰 내용 중 키워드가 포함된 리뷰만 추출
    keyword_reviews = df_reviews[df_reviews['content'].str.contains(keyword)]
    
    # 해당 키워드로 필터링 된 리뷰가 없는 경우, 다음 키워드로 넘어가기
    if keyword_reviews.empty:
        print(f"'{keyword}'에 대한 리뷰를 찾을 수 없습니다.")
        continue

    # 해당 키워드로 필터링 된 리뷰들의 평균 점수 계산
    avg_score = keyword_reviews['score'].mean()
    # 딕셔너리의 key값을 "키워드_score" 형태로 저장하기 위한 문자열 생성
    key_name = f"{keyword}_score"
    # 계산한 평균 점수를 딕셔너리에 저장
    keyword_scores[key_name] = avg_score
    # 결과를 소수점 두 자리까지만 출력
    print(f"{key_name}: {avg_score:.2f}")

# 최종 키워드별 평균 점수 출력
print(keyword_scores)
# Out:
# 렉_score: 2.72
# 업데이트_score: 2.33
# 패치_score: 1.50
# 팅_score: 2.34
# 로딩_score: 2.12
# rpg_score: 3.29
# '섭종'에 대한 리뷰를 찾을 수 없습니다.
# 스토리_score: 3.81
# 캐릭터_score: 3.00
# 데미지_score: 1.00
# 딜_score: 2.00
# '콘셉트'에 대한 리뷰를 찾을 수 없습니다.
# 'BGM'에 대한 리뷰를 찾을 수 없습니다.
# '노래'에 대한 리뷰를 찾을 수 없습니다.
# 의상_score: 4.50
# 커스터마이징_score: 2.75
# 자유도_score: 5.00
# 컨텐츠_score: 3.45
# '플레티넘'에 대한 리뷰를 찾을 수 없습니다.
# '챌린저'에 대한 리뷰를 찾을 수 없습니다.
# '다이아몬드'에 대한 리뷰를 찾을 수 없습니다.
# '아처'에 대한 리뷰를 찾을 수 없습니다.
# '서포터'에 대한 리뷰를 찾을 수 없습니다.
# 갓겜_score: 4.59
# 레전드_score: 3.00
# 가챠_score: 2.00
# 무과금_score: 3.52
# 과금_score: 2.99
# '일러스트'에 대한 리뷰를 찾을 수 없습니다.
# 튜토리얼_score: 1.55
# 유튜브_score: 2.33
# 광고_score: 1.60
# 그래픽_score: 3.94
# 밸런스_score: 1.00
# 조작감_score: 3.43
# ai_score: 1.75
# 버그_score: 2.67
# 데이터_score: 2.29
# 와이파이_score: 2.67
# 난이도_score: 3.00
# '억까'에 대한 리뷰를 찾을 수 없습니다.
# 노잼_score: 1.29
# 스릴_score: 4.60
# '짭퉁'에 대한 리뷰를 찾을 수 없습니다.
# 꿀잼_score: 4.97
# 트롤_score: 3.64
# '리듬'에 대한 리뷰를 찾을 수 없습니다.
# '랭크'에 대한 리뷰를 찾을 수 없습니다.
# 미션_score: 3.43
# 중독성_score: 4.50
# '루비'에 대한 리뷰를 찾을 수 없습니다.
# 시스템_score: 2.92
# 자동_score: 3.15
# 타격감_score: 4.46
# 업글_score: 2.67
# 핵_score: 2.33
# 편의성_score: 3.00
# '불친절'에 대한 리뷰를 찾을 수 없습니다.
# 최적화_score: 2.66
# 전술_score: 2.00
# 운영_score: 2.48
# 소통_score: 5.00
# 현실감_score: 2.00
# 네트워크_score: 1.50
# '킬링타임'에 대한 리뷰를 찾을 수 없습니다.
# {'렉_score': 2.7218934911242605, '업데이트_score': 2.3333333333333335, '패치_score': 1.5, '팅_score': 2.335714285714286, '로딩_score': 2.125, 'rpg_score': 3.2941176470588234, '스토리_score': 3.808219178082192, '캐릭터_score': 3.0, '데미지_score': 1.0, '딜_score': 2.0, '의상_score': 4.5, '커스터마이징_score': 2.75, '자유도_score': 5.0, '컨텐츠_score': 3.4545454545454546, '갓겜_score': 4.590909090909091, '레전드_score': 3.0, '가챠_score': 2.0, '무과금_score': 3.5208333333333335, '과금_score': 2.9857142857142858, '튜토리얼_score': 1.5454545454545454, '유튜브_score': 2.3333333333333335, '광고_score': 1.6, '그래픽_score': 3.9356223175965663, '밸런스_score': 1.0, '조작감_score': 3.4285714285714284, 'ai_score': 1.75, '버그_score': 2.6666666666666665, '데이터_score': 2.2857142857142856, '와이파이_score': 2.6666666666666665, '난이도_score': 3.0, '노잼_score': 1.2941176470588236, '스릴_score': 4.6, '꿀잼_score': 4.9655172413793105, '트롤_score': 3.6363636363636362, '미션_score': 3.4285714285714284, '중독성_score': 4.5, '시스템_score': 2.9166666666666665, '자동_score': 3.15, '타격감_score': 4.462365591397849, '업글_score': 2.6666666666666665, '핵_score': 2.3333333333333335, '편의성_score': 3.0, '최적화_score': 2.6575342465753424, '전술_score': 2.0, '운영_score': 2.4761904761904763, '소통_score': 5.0, '현실감_score': 2.0, '네트워크_score': 1.5}

# %% [markdown]
# ## 입력 데이터 전처리
# #### 형태소 분석 후 모델 및 벡터라이즈 불러와서 예측 (긍/부정)

# %%
# 입력 데이터 전처리

# 필요한 라이브러리 및 모듈을 임포트합니다.
import warnings
from sklearn.neural_network import MLPClassifier, MLPRegressor
from joblib import load
import rhinoMorph
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from joblib import load

# 경고 메시지를 무시합니다.
warnings.filterwarnings("ignore")

# CSV 파일을 읽어 데이터프레임으로 변환합니다.
data = pd.read_csv('C:/Temp/df_reviews_num.csv')  # 평점 3,4 제거 안한 data 가져오기

# 불필요한 컬럼 제거
del data['Unnamed: 0'] 

# Rhino 형태소 분석기 로딩
rn = rhinoMorph.startRhino()

# 불용어 사전을 정의합니다. 
# 이 불용어들은 형태소 분석 후 결과에서 제거될 단어들입니다.
stopwords = ["가", "가까스로", "가령", "각", "각각", "각자", "각종", "갖고말하자면", "같다", "같이",
    "개의치않고", "거니와", "거바", "거의", "것", "것과 같이", "것들", "게다가", "게우다", "겨우",
    "견지에서", "결과에 이르다", "결국", "결론을 낼 수 있다", "겸사겸사", "고려하면", "고로", "곧",
    "공동으로", "과", "과연", "관계가 있다", "관계없이", "관련이 있다", "관하여", "관한", "관해서는",
    "구", "구체적으로", "구토하다", "그", "그들", "그때", "그래", "그래도", "그래서", "그러나",
    "그러니", "그러니까", "그러면", "그러므로", "그러한즉", "그런 까닭에", "그런데", "그런즉",
    "그럼", "그럼에도 불구하고", "그렇게 함으로써", "그렇지", "그렇지 않다면", "그렇지 않으면",
    "그렇지만", "그렇지않으면", "그리고", "그리하여", "그만이다", "그에 따르는", "그위에", "그저",
    "그중에서", "그치지 않다", "근거로", "근거하여", "기대여", "기점으로", "기준으로", "기타",
    "까닭으로", "까악", "까지", "까지 미치다", "까지도", "꽈당", "끙끙", "끼익", "나", "나머지는",
    "남들", "남짓", "너", "너희", "너희들", "네", "넷", "년", "논하지 않다", "놀라다", "누가 알겠는가",
    "누구", "다른", "다른 방면으로", "다만", "다섯", "다소", "다수", "다시 말하자면", "다시말하면",
    "다음", "다음에", "다음으로", "단지", "답다", "당신", "당장", "대로 하다", "대하면", "대하여",
    "대해 말하자면", "대해서", "댕그", "더구나", "더군다나", "더라도", "더불어", "더욱더", "더욱이는",
    "도달하다", "도착하다", "동시에", "동안", "된바에야", "된이상", "두번째로", "둘", "둥둥", "뒤따라",
    "뒤이어", "든간에", "들", "등", "등등", "딩동", "따라", "따라서", "따위", "따지지 않다",
    "딱", "때", "때가 되어", "때문에", "또", "또한", "뚝뚝", "라 해도", "령", "로", "로 인하여",
    "로부터", "로써", "륙", "를", "마음대로", "마저", "마저도", "마치", "막론하고", "만 못하다",
    "만약", "만약에", "만은 아니다", "만이 아니다", "만일", "만큼", "말하자면", "말할것도 없고",
    "매", "매번", "메쓰겁다", "몇", "모", "모두", "무렵", "무릎쓰고", "무슨", "무엇", "무엇때문에",
    "물론", "및", "바꾸어말하면", "바꾸어말하자면", "바꾸어서 말하면", "바꾸어서 한다면", "바꿔 말하면",
    "바로", "바와같이", "밖에 안된다", "반대로", "반대로 말하자면", "반드시", "버금", "보는데서",
    "보다더", "보드득", "본대로", "봐", "봐라", "부류의 사람들", "부터", "불구하고", "불문하고",
    "붕붕", "비걱거리다", "비교적", "비길수 없다", "비로소", "비록", "비슷하다", "비추어 보아",
    "비하면", "뿐만 아니라", "뿐만아니라", "뿐이다", "삐걱", "삐걱거리다", "사", "삼", "상대적으로 말하자면",
    "생각한대로", "설령", "설마", "설사", "셋", "소생", "소인", "솨", "쉿", "습니까", "습니다",
    "시각", "시간", "시작하여", "시초에", "시키다", "실로", "심지어", "아", "아니", "아니나다를가",
    "아니라면", "아니면", "아니었다면", "아래윗", "아무거나", "아무도", "아야", "아울러", "아이",
    "아이고", "아이구", "아이야", "아이쿠", "아하", "아홉", "안 그러면", "않기 위하여", "않기 위해서",
    "알 수 있다", "알았어", "앗", "앞에서", "앞의것", "야", "약간", "양자", "어", "어기여차",
    "어느", "어느 년도", "어느것", "어느곳", "어느때", "어느쪽", "어느해", "어디", "어때", "어떠한",
    "어떤", "어떤것", "어떤것들", "어떻게", "어떻해", "어이", "어째서", "어쨋든", "어쩔수 없다",
    "어찌", "어찌됏든", "어찌됏어", "어찌하든지", "어찌하여", "언제", "언젠가", "얼마", "얼마 안 되는 것",
    "얼마간", "얼마나", "얼마든지", "얼마만큼", "얼마큼", "엉엉", "에", "에 가서", "에 달려 있다",
    "에 대해", "에 있다", "에 한하다", "에게", "에서", "여", "여기", "여덟", "여러분", "여보시오",
    "여부", "여섯", "여전히", "여차", "연관되다", "연이서", "영", "영차", "옆사람", "예", "예를 들면",
    "예를 들자면", "예컨대", "예하면", "오", "오로지", "오르다", "오자마자", "오직", "오호", "오히려",
    "와", "와 같은 사람들", "와르르", "와아", "왜", "왜냐하면", "외에도", "요만큼", "요만한 것",
    "요만한걸", "요컨대", "우르르", "우리", "우리들", "우선", "우에 종합한것과같이", "운운", "월",
    "위에서 서술한바와같이", "위하여", "위해서", "윙윙", "육", "으로", "으로 인하여", "으로서", "으로써",
    "을", "응", "응당", "의", "의거하여", "의지하여", "의해", "의해되다", "의해서", "이", "이 되다",
    "이 때문에", "이 밖에", "이 외에", "이 정도의", "이것", "이곳", "이때", "이라면", "이래", "이러이러하다",
    "이러한", "이런", "이럴정도로", "이렇게 많은 것", "이렇게되면", "이렇게말하자면", "이렇구나", "이로 인하여",
    "이르기까지", "이리하여", "이만큼", "이번", "이봐", "이상", "이어서", "이었다", "이와 같다",
    "이와 같은", "이와 반대로", "이와같다면", "이외에도", "이용하여", "이유만으로", "이젠", "이지만",
    "이쪽", "이천구", "이천육", "이천칠", "이천팔", "인 듯하다", "인젠", "일", "일것이다", "일곱",
    "일단", "일때", "일반적으로", "일지라도", "임에 틀림없다", "입각하여", "입장에서", "잇따라", "있다",
    "자", "자기", "자기집", "자마자", "자신", "잠깐", "잠시", "저", "저것", "저것만큼", "저기", "저쪽",
    "저희", "전부", "전자", "전후", "점에서 보아", "정도에 이르다", "제", "제각기", "제외하고", "조금",
    "조차", "조차도", "졸졸", "좀", "좋아", "좍좍", "주룩주룩", "주저하지 않고", "줄은 몰랏다", "줄은모른다",
    "중에서", "중의하나", "즈음하여", "즉", "즉시", "지각", "지금", "지든지", "지만", "지말고",
    "진짜로", "쪽으로", "차라리", "참", "참나", "첫번째로", "쳇", "총적으로", "총적으로 말하면",
    "총적으로 보면", "칠", "콸콸", "쾅쾅", "쿵", "타다", "타인", "탕탕", "토하다", "통하여",
    "툭", "퉤", "틈타", "팍", "팔", "퍽", "펄렁", "하", "하게될것이다", "하게하다", "하겠는가",
    "하고 있다", "하고있었다", "하곤하였다", "하구나", "하기 때문에", "하기 위하여", "하기는한데",
    "하기만 하면", "하기보다는", "하기에", "하나", "하느니", "하는 김에", "하는 편이 낫다",
    "하는것도", "하는것만 못하다", "하는것이 낫다", "하는바", "하더라도", "하도다", "하도록시키다",
    "하도록하다", "하든지", "하려고하다", "하마터면", "하면 할수록", "하면된다", "하면서", "하물며",
    "하여금", "하여야", "하자마자", "하지 않는다면", "하지 않도록", "하지마", "하지마라", "하지만",
    "하하", "한 까닭에", "한 이유는", "한 후", "한다면", "한다면 몰라도", "한켠으로는", "한항목",
    "할 따름이다", "할 생각이다", "할 줄 안다", "할 지경이다", "할 힘이 있다", "할때", "할만하다",
    "할망정", "할뿐", "할수있다", "할수있어", "할줄알다", "할지라도", "할지언정", "함께", "해도된다",
    "해도좋다", "해봐요", "해서는 안된다", "해야한다", "해요", "했어요", "향하다", "향하여", "향해서",
    "허", "허걱", "허허", "헉", "헉헉", "헐떡헐떡", "형식으로 쓰여", "혹시", "혹은", "혼자",
    "훨씬", "휘익", "휴", "흐흐", "흥", "힘입어",'ㄱ','ㄲ','ㄴ','ㄷ','ㄸ','ㄹ','ㅁ','ㅂ','ㅃ','ㅅ','ㅆ',
    'ㅇ','ㅈ','ㅉ','ㅊ','ㅋ','ㅌ','ㅍ','ㅎ'
]

def analyze_pos(df, stopwords=stopwords):   # 형태소 분석 함수
    new_data = []

    # 데이터프레임의 각 행에 대해서 반복합니다.
    for i, row in df.iterrows():
        try:
            data_each = str(row['content'])
            data_score = row['score']
            data_tuc = row['thumbsUpCount']
            data_num = row['num']  # num 컬럼 값을 가져옵니다.

            # 형태소 분석 및 품사 태깅을 진행합니다.
            morphed_data_each = rhinoMorph.onlyMorph_list(rn, data_each, pos=['NNG', 'VV', 'VA', 'XR', 'IC', 'MAG','EC','MAJ'], eomi=True, xrVv=True)

            # 결과에서 불용어를 제거합니다.
            if stopwords:
                morphed_data_each = [word for word in morphed_data_each if word not in stopwords]

            # 형태소들을 공백을 기준으로 합쳐서 하나의 문자열로 만듭니다.
            merged_data_each = ' '.join(morphed_data_each)

            # 형태소 분석 결과가 비어있지 않으면 새로운 데이터 목록에 추가합니다.
            if merged_data_each:
                new_data.append([data_score, merged_data_each, data_tuc, data_num])  # num 컬럼 값도 추가합니다.
        except Exception as e:
            # 오류 발생 시 오류 메시지를 출력합니다.
            print(f"Error occurred at index {i}: {e}")
            continue

    # 새로운 데이터 목록을 데이터프레임으로 변환하여 반환합니다.
    df_new = pd.DataFrame(new_data, columns=['score', 'content', 'thumbsUpCount', 'num'])  # num 컬럼도 포함

    return df_new

# 형태소 분석 수행
data_analyzed = analyze_pos(data, stopwords)

# TF-IDF 벡터라이저 로드
# 사전에 학습된 TF-IDF 벡터라이저를 joblib로부터 불러옵니다.
tfidf_vectorizer = load("C:/Users/AI/Desktop/Hagsim_project/new_project/csv/Project R/Project_R/tfidf_vectorizer.joblib")

# 형태소 분석이 완료된 'content' 칼럼을 이용하여 TF-IDF 변환을 수행합니다.
# 이 변환을 통해 리뷰 텍스트를 수치 데이터로 바꾸어줍니다.
tfidf_matrix = tfidf_vectorizer.transform(data_analyzed['content'])

# 변환된 TF-IDF 행렬을 데이터프레임 형식으로 변환합니다.
# 이렇게 하면 각 단어별 TF-IDF 점수를 볼 수 있습니다.
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names())

# 미리 학습된 로지스틱 회귀 모델을 joblib로부터 불러옵니다.
model = load("C:/Users/AI/Desktop/Hagsim_project/new_project/csv/Project R/Project_R/logreg2.joblib")

# TF-IDF로 변환된 리뷰 텍스트 데이터를 사용하여 긍정/부정 예측을 수행합니다.
predictions = model.predict(tfidf_df)

# 예측 결과를 'sentiment'라는 새로운 칼럼에 저장합니다.
# 여기서 'sentiment' 칼럼에는 각 리뷰에 대한 긍정/부정 예측 결과가 저장됩니다.
data_analyzed['sentiment'] = predictions
# Out:
# C:\Users\AI\Anaconda3\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):
# filepath:  C:\Users\AI\Anaconda3\lib\site-packages
# classpath:  C:\Users\AI\Anaconda3\lib\site-packages\rhinoMorph/lib/rhino.jar
# RHINO started!

# %% [markdown]
# ### 데이터 분할 및 전체 리뷰에서 빈도가 높은 키워드 5개 출력

# %%
# 긍정 리뷰와 부정 리뷰를 나누어 분석할 데이터프레임 생성
# 'sentiment' 칼럼의 값이 1인 경우 긍정 리뷰, -1인 경우 부정 리뷰로 판단하여 데이터를 분리합니다.
data_positive = data_analyzed[data_analyzed['sentiment'] == 1]
data_negative = data_analyzed[data_analyzed['sentiment'] == -1]

# 긍정 리뷰에서 빈도가 높은 키워드 5개 추출
# 각 키워드 그룹의 첫 번째 키워드를 딕셔너리의 키로 사용하고 빈도수를 0으로 초기화합니다.
keyword_frequencies_pos = {keyword_group[0]: 0 for keyword_group in keywords_grouped}
for content in data_positive['content']:
    for keyword_group in keywords_grouped:
        # 각 리뷰 내용에서 해당 키워드 그룹의 키워드가 몇 번 등장하는지 카운트합니다.
        group_frequency = sum(keyword in content for keyword in keyword_group)
        keyword_frequencies_pos[keyword_group[0]] += group_frequency
# 빈도수를 기준으로 상위 5개의 키워드를 선택합니다.
top_5_keywords_pos = dict(sorted(keyword_frequencies_pos.items(), key=lambda x: x[1], reverse=True)[:5])
print("상위 5개의 긍정 리뷰 키워드:", top_5_keywords_pos)

# 부정 리뷰에서 빈도가 높은 키워드 5개 추출
# 부정 리뷰 중 'content' 칼럼에 NaN값이 있는 행을 제거합니다.
data_negative.dropna(subset=['content'], inplace=True)
# 각 키워드 그룹의 첫 번째 키워드를 딕셔너리의 키로 사용하고 빈도수를 0으로 초기화합니다.
keyword_frequencies_neg = {keyword_group[0]: 0 for keyword_group in keywords_grouped}
for content in data_negative['content']:
    for keyword_group in keywords_grouped:
        # 각 리뷰 내용에서 해당 키워드 그룹의 키워드가 몇 번 등장하는지 카운트합니다.
        group_frequency = sum(keyword in content for keyword in keyword_group)
        keyword_frequencies_neg[keyword_group[0]] += group_frequency
# 빈도수를 기준으로 상위 5개의 키워드를 선택합니다.
top_5_keywords_neg = dict(sorted(keyword_frequencies_neg.items(), key=lambda x: x[1], reverse=True)[:5])
print("상위 5개의 부정 리뷰 키워드:", top_5_keywords_neg)
# Out:
# 상위 5개의 긍정 리뷰 키워드: {'그래픽': 169, '타격감': 80, '과금': 59, '캐릭터': 58, '난이도': 50}
# 상위 5개의 부정 리뷰 키워드: {'최적화': 198, '렉': 162, '과금': 128, '캐릭터': 90, '그래픽': 72}

# %% [markdown]
# ### 키워드 별로 추천 기준 상위 10개의 댓글을 가져옴

# %%
# 키워드 그룹을 찾는 함수
def get_keyword_group(keyword):
    # 주어진 키워드가 어느 키워드 그룹에 속하는지를 확인합니다.
    for group in keywords_grouped:
        if keyword in group:
            return group
    # 해당 키워드가 특정 그룹에 속하지 않을 경우 그 키워드만 반환합니다.
    return [keyword]

# 긍정 리뷰에 대한 상위 10개 댓글 가져오기
top_10_reviews_by_keyword_pos = []
# 상위 5개 긍정 키워드를 순회합니다.
for key_pos, frequency in top_5_keywords_pos.items():
    # 해당 키워드가 속한 그룹을 찾습니다.
    key_pos_group = get_keyword_group(key_pos)
    # 그룹 내의 키워드들을 정규식 패턴으로 변환합니다.
    keyword_pattern = "|".join(key_pos_group)
    # 해당 키워드 패턴이 포함된 긍정 리뷰들을 필터링합니다.
    keyword_reviews = data_positive[data_positive['content'].str.contains(keyword_pattern, regex=True)]
    # 'thumbsUpCount' 기준으로 리뷰들을 내림차순으로 정렬합니다.
    sorted_reviews = keyword_reviews.sort_values(by='thumbsUpCount', ascending=False)
    # 상위 10개의 리뷰 내용만을 추출합니다.
    top_10_reviews = sorted_reviews.head(10)['content'].tolist()
    # 결과를 리스트에 추가합니다.
    top_10_reviews_by_keyword_pos.append(top_10_reviews)

# 부정 리뷰에 대한 상위 10개 댓글 가져오기
top_10_reviews_by_keyword_neg = []
# 상위 5개 부정 키워드를 순회합니다.
for key_neg, frequency in top_5_keywords_neg.items():
    # 해당 키워드가 속한 그룹을 찾습니다.
    key_neg_group = get_keyword_group(key_neg)
    # 그룹 내의 키워드들을 정규식 패턴으로 변환합니다.
    keyword_pattern = "|".join(key_neg_group)
    # 해당 키워드 패턴이 포함된 부정 리뷰들을 필터링합니다.
    keyword_reviews = data_negative[data_negative['content'].str.contains(keyword_pattern, regex=True)]
    # 'thumbsUpCount' 기준으로 리뷰들을 내림차순으로 정렬합니다.
    sorted_reviews = keyword_reviews.sort_values(by='thumbsUpCount', ascending=False)
    # 상위 10개의 리뷰 내용만을 추출합니다.
    top_10_reviews = sorted_reviews.head(10)['content'].tolist()
    # 결과를 리스트에 추가합니다.
    top_10_reviews_by_keyword_neg.append(top_10_reviews)

# %% [markdown]
# ### 그 형태소 분석된 데이터와 원본 데이터 리뷰 비교

# %%
# 선택한 리뷰를 원본 데이터에서 찾아서 보여주는 함수
def show_original_review(selected_review_num, original_data):
    # 원본 데이터에서 선택한 리뷰 번호에 해당하는 리뷰 내용을 찾습니다.
    selected_review = original_data[original_data['num'] == selected_review_num]['content'].values[0]
    # 해당 리뷰 내용을 출력합니다.
    print("리뷰 내용입니다:")
    print(selected_review)
    print()

# 각 키워드별로 상위 10개 리뷰를 출력하면서 선택한 리뷰의 원본을 보여주는 부분
# 긍정 키워드에 대한 상위 10개 리뷰 출력
for i, (key_pos, reviews) in enumerate(zip(top_5_keywords_pos.keys(), top_10_reviews_by_keyword_pos)):
    print(f"Keyword {i+1}: {key_pos}")
    for j, review in enumerate(reviews, start=1):
        # 리뷰 내용을 출력합니다.
        print(f"Review {j}: {review}")
        # 해당 리뷰의 번호(num) 값을 찾습니다.
        selected_review_num = data_positive[data_positive['content'] == review]['num'].values[0]
        # 원본 데이터에서 해당 리뷰의 내용을 보여주는 함수를 호출합니다.
        show_original_review(selected_review_num, data)
    print()

# 부정 키워드에 대한 상위 10개 리뷰 출력
for i, (key_neg, reviews) in enumerate(zip(top_5_keywords_neg.keys(), top_10_reviews_by_keyword_neg)):
    print(f"Keyword {i+1}: {key_neg}")
    for j, review in enumerate(reviews, start=1):
        # 리뷰 내용을 출력합니다.
        print(f"Review {j}: {review}")
        # 해당 리뷰의 번호(num) 값을 찾습니다.
        selected_review_num = data_negative[data_negative['content'] == review]['num'].values[0]
        # 원본 데이터에서 해당 리뷰의 내용을 보여주는 함수를 호출합니다.
        show_original_review(selected_review_num, data)
    print()
# Out:
# Keyword 1: 그래픽
# Review 1: 모바일 게임 크다 기대 하다 지 는데 상당히 완성도 게 나오다 아서 그래픽 그래픽 세세하다 커스터마이징 잘 되다 최적화 깔끔하다 정말 좋다 특히 모바일 깔끔하다 조작 감 정말 ㅋㅋ 앞 운영 잘 하다 ㄴ다면 초 갓겜 되다 지
# 리뷰 내용입니다:
# 모바일 게임으로서는 큰 기대를 하지 않았는데 상당히 완성도 있게 나와서 놀랐습니다. 그래픽도 그래픽이지만 세세한 커스터마이징, 나름 잘된 최적화와 깔끔한 UI도 정말 좋네요. 특히 모바일임에도 깔끔한 조작감에 정말 놀랐습니다ㅋㅋ 앞으로 운영만 잘한다면 초갓겜이 될 수 있지 않을까 싶네요
#
# Review 2: 재미있다 그래픽 좋다 고 캐릭터 이쁘다 고
# 리뷰 내용입니다:
# 재미있을거 같아요 그래픽 좋고 캐릭터도 이쁘고
#
# Review 3: 가다 주다 모르다 게임 그래픽 며 캐릭터 아이템 지 시스템 잘 구축 되다 고 슈트 갈아입다 으면서 다양 킬 접다 하다 최고 장점 별 고 ^^ 정말 감사 하다 게임 만들다 어서 깊다 노고 진심 느끼다 앞 더 번창하다 ^^
# 리뷰 내용입니다:
# 시간 가는줄 모르는 게임입니다~!~그래픽이며 캐릭 아이템 여러가지 시스템으로 잘 구축이되어있고 슈트를3개씩이나 갈아입으면서 다양한스킬들을 접할수 있어 최고의 장점입니다!! 별100개드리고싶습니다!!^^ 정말감사합니다 이런게임을 만들어주셔서 깊은노고가 진심으로 느껴집니다 앞으로도 더 번창하세요~!~!^^
#
# Review 4: 그래픽 잘 돌아가다 신기하다 이쁘다 캐릭터 화면 구성 레이아웃 완벽 중독성 재미 글쎄 아직 오랫만 오래 해보다 고 게임 나이스
# 리뷰 내용입니다:
# 쩌는 그래픽 잘돌아가는게 신기하다. 이쁜 캐릭터와 화면 구성 레이아웃이 완벽 ㅎ 중독성 있는 재미는 글쎄, 아직 ㅎ 하지만 오랫만에 오래 해보고 싶은 게임 나이스
#
# Review 5: 그래픽 너무 좋다 최적화 나쁘다 레 검다 사막 모바일 합치다 놓다 느낌 시작 하다 ㄴ지 과금 잘 모르다 PC 하다 모바일 하다 아도 재미있다
# 리뷰 내용입니다:
# 그래픽 너무 좋음. 최적화도 나쁘지않음. 워프레임+검은사막모바일을 합쳐놓은듯한 느낌. 시작한지 3일째라 과금은 잘 모르겠음. pc로 해도, 모바일로해도 재미있음.
#
# Review 6: 재미있다 간만 그래픽 스토리 구성 마음 들다 는 게임 나오다 기준 즐 게임 하다
# 리뷰 내용입니다:
# 재밌네요 간만에 그래픽과 스토리구성 맘에 드는 게임이 나왔네요. (제 기준 ㅋ) 즐겜 하겠습니다.
#
# Review 7: 게임 비하다 아서 그래픽 완전 좋다 고 타격감 좋다 고 다 좋다 단점 가지다 발열 심하다 배터리 너무 빨리다 땀 이점 고쳐다
# 리뷰 내용입니다:
# 다른 게임에 비해선 그래픽 완전 좋고, 타격감 좋고 다 좋네여~ 그런데..!! 단점은 딱 두가지있네요 발열이 심함 배터리 너무 빨리땀 이점만 고쳐주세요
#
# Review 8: 역시 기대다 저버리다 지 오래전 꿈꾸다 오다 제대로 만들다 드디어 만나다 콘솔 그래픽 콘솔 연출력 아직 초반 취향 맞다 게임 찾다
# 리뷰 내용입니다:
# 역시 기대를 저버리지 않네요 제가 오래전부터 꿈꿔오던 제대로만든 sf장르의mmorpg 드디어 만나보네요. 콘솔급 그래픽에 콘솔급 연출력 아직 초반이지만 제 취향에 딱 맞는 게임을 찾은것 같네요~
#
# Review 9: 새롭다 고 넘넘 재미있다 타격감 고 그래픽 끝내다 고 의상 교체하다 면 무기 하다 고 나오다 인물 전환되다 진행 도 되다 고 너무 재미나다 ^^
# 리뷰 내용입니다:
# 새롭고 넘넘 재밌네여 타격감도 있고 그래픽 끝내주고 다른 의상으로 교체하면 다른무기로도 할수 있고 나오는 인물들로 전환되어 진행도 되고 넘 재미나요~^^
#
# Review 10: 입문 그래픽 짱
# 리뷰 내용입니다:
# 입문전 그래픽짱인듯요!!
#
#
# Keyword 2: 타격감
# Review 1: ㄴ가 컷 씬 너무 뜬금없다 고 부자연스럽다 총 칼 사용하다 는데 타격감 부드럽다 지 임팩트 지 고 너무 스르륵 지나가다 첫인상 전혀 강하다 지 고 인디 게임 더 부족하다 다고 생각되다 카카오 게임 개인적 응원하다 곳 라 좋다 게임 만들다 기대다 하다 업데이트 기대다 하다
# 리뷰 내용입니다:
# 뭔가 컷씬이나 qte같은 것들이 너무 뜬금없고 부자연스럽습니다. 총이나 칼을 사용하는데 타격감이 부드럽지도, 임팩트 있지도 않고 너무 스르륵 지나갑니다. 첫인상이 전혀 강하지않고 인디게임보다도 더 부족하다고 생각됩니다. 카카오게임즈는 개인적으로 응원하는 곳이라 좀 좋은 게임을 만들기를 기대합니다! 업데이트를 기대하겠습니다
#
# Review 2: 게임 비하다 아서 그래픽 완전 좋다 고 타격감 좋다 고 다 좋다 단점 가지다 발열 심하다 배터리 너무 빨리다 땀 이점 고쳐다
# 리뷰 내용입니다:
# 다른 게임에 비해선 그래픽 완전 좋고, 타격감 좋고 다 좋네여~ 그런데..!! 단점은 딱 두가지있네요 발열이 심함 배터리 너무 빨리땀 이점만 고쳐주세요
#
# Review 3: 게임 너무 재미있다 타격감 괜찮다 고 자사 돌리다 면서 창 기능 사용하다 드라마 영화 웹툰 보다 게 만들다 고 원하다 모바일 게임 느낌 라 좋다
# 리뷰 내용입니다:
# 게임이 너무 재미있어요. 타격감도 괜찮고 자사 돌리면서 창 기능을 사용해 드라마나 영화 웹툰 유튜브등 볼수있게 만들어주시고 내가 원하는 모바일게임이 이런느낌이라 좋습니다.
#
# Review 4: 새롭다 고 넘넘 재미있다 타격감 고 그래픽 끝내다 고 의상 교체하다 면 무기 하다 고 나오다 인물 전환되다 진행 도 되다 고 너무 재미나다 ^^
# 리뷰 내용입니다:
# 새롭고 넘넘 재밌네여 타격감도 있고 그래픽 끝내주고 다른 의상으로 교체하면 다른무기로도 할수 있고 나오는 인물들로 전환되어 진행도 되고 넘 재미나요~^^
#
# Review 5: 근래 해보다 타격감 좋다 아직 초반 라 그렇다 ㄴ지 게임 이해도 낮다 그렇다 ㄴ지 어렵다 듯 느낌 의상 다양 예쁘다
# 리뷰 내용입니다:
# 근래 해본것중 타격감이 좋네요. 아직 초반이라그런지 게임 이해도가 낮아서그런지 좀 어려운듯한 느낌이 있음. 의상이 다양하고 예쁨.
#
# Review 6: 재가 게임 플레이 하다 는데 그래픽 최고 타격감 최고 스토리 탄탄하다
# 리뷰 내용입니다:
# 재가 이 게임을 잠깐 플레이 했는데 그래픽도 최고 타격감 최고네요 스토리도 탄탄하고요
#
# Review 7: 시작 안되다 타격감 공속 보조 무기 엑 감 좋다 더 하다 아직 만족 즐기다 고
# 리뷰 내용입니다:
# 일단 시작한지는 얼마안됐지만 타격감이나 공속 보조무기등 엑션감이 좋네요...좀더 해봐야 하겠지만 아직은 만족하고 즐기고 있습니다...
#
# Review 8: 그래픽 타격감 손쉽다 사냥 만족
# 리뷰 내용입니다:
# 그래픽 타격감 손쉬운 사냥 만족
#
# Review 9: 기대하다 잘 들다 그래픽 커스터마이징 요즘 출시 게임 상향 평준화 되다 언급하다 필요 없다 고 장르 전투 액션 타격감 후판 전투 컨트롤 하다 재미 앞 잘 운영 하다 아서 갓 게임 되다 으면 좋다 화이팅
# 리뷰 내용입니다:
# 기대했던것 만큼 잘만들어진것 같네요, 그래픽, 커마 는 요즘 출시 겜은 상향평준화 되어 언급할필요 없고, sf장르, 전투 액션 타격감,후판정 전투로 컨트롤 하는재미등 앞으로 잘운영해서 갓게임 되었으면 좋겠습니다.화이팅
#
# Review 10: 그래픽 좋다 고 타격감 좋다 고 근데 업그레이드 시스템 너무 복잡 어렵다
# 리뷰 내용입니다:
# 그래픽 좋고, 타격감 좋고 근데 업그레이드나 기타시스템이 너무 복잡하고 어렵네요
#
#
# Keyword 3: 과금
# Review 1: 그래픽 너무 좋다 최적화 나쁘다 레 검다 사막 모바일 합치다 놓다 느낌 시작 하다 ㄴ지 과금 잘 모르다 PC 하다 모바일 하다 아도 재미있다
# 리뷰 내용입니다:
# 그래픽 너무 좋음. 최적화도 나쁘지않음. 워프레임+검은사막모바일을 합쳐놓은듯한 느낌. 시작한지 3일째라 과금은 잘 모르겠음. pc로 해도, 모바일로해도 재미있음.
#
# Review 2: 제발 현질 안 하다 솔로 윙 가능하다 으면 좋다
# 리뷰 내용입니다:
# 제발.. 현질 안해도 솔로윙 가능했으면 좋겠네요
#
# Review 3: 정말 취향 취향 긴하다 게임 편파 없이 좋다 요즘 게임 핵 과금 러 생각하다 게임 과금 없이 투자하다 면 어렵다 게임 겔 렉 울트라 정도 되다 어야 최고 사양 즐기다 수 발열 없다
# 리뷰 내용입니다:
# 정말 잘만들었습니닺 취향은 취향이긴하지만 게임성은 편파없이 좋습니다 요즘게임은 핵과금러만 생각하는대 이겜은 과금없이도 시간만 투자하면 어려운게임이 아닌거같내요 그리고 겔렉시 울트라 s21정도 되야 최고사양으로 즐길수있습니다 발열없습니다
#
# Review 4: 그래픽 스토리 정말 좋다 은데 많이 낮다 고 과금 너무 유도 하다 아서 아쉽다 뽑다 기권 주다 어도 좋다 으 안 나오다 광고 보다 고 재미있다 아서 는데 계속 하다 되다 ㄹ지 의문
# 리뷰 내용입니다:
# 그래픽이나 스토리는 정말 좋은데 드랍률도 많이 낮고 과금을 너무 유도 하시는 것 같아서 아쉽습니다. 뽑기권을 줘도 좋으거는 하나도 안나오네요 광고 보고 재밌을 것 같아서 했는데... 계속 해야될지.. 의문입니다.
#
# Review 5: 게임 재미있다 최적화 부탁 며 무소 과금 성장 재미 요소 많다 업데이트 부탁 드리다
# 리뷰 내용입니다:
# 게임은 재밌습니다 최적화부탁드리며, 무소과금 의 성장 재미요소도 많은업데이트부탁드립니다
#
# Review 6: 과금 하다 으면 좋다
# 리뷰 내용입니다:
# 무과금도 할수 있으면 좋겠습니다
#
# Review 7: 아직 발열 끊기다 많다 면 수록 재미 고 스토리 재미있다 과금 가능하다
# 리뷰 내용입니다:
# 아직은 발열도 끊김도 많지만 하면 할 수록 재미도 있고 스토리가 재미있네여 20레벨까진 무과금도 가능해요
#
# Review 8: 주 캐릭터 전환하다 설정 괜찮다 그래픽 좋다 과금 해보다 중인 막 시작하다 아서 과금 하다 을지 모르다
# 리뷰 내용입니다:
# 주케릭을 전환한다는 설정도 나름 괜찬음.그래픽 좋음. 일단.무과금으로 해보는 중인데..막.시작해서 어디까지 무과금으로 할수있을진 모르지만..일단 ㄱㄱ
#
# Review 9: 그래픽 좋다 고 과금 가능하다 듯 ㅋㅋ
# 리뷰 내용입니다:
# 그래픽이 좋고 무과금 가능할듯ㅋㅋ
#
# Review 10: 과금 덜하다 면 좋다 텐
# 리뷰 내용입니다:
# 과금만 덜하면 좋을텐대
#
#
# Keyword 4: 캐릭터
# Review 1: 재미있다 그래픽 좋다 고 캐릭터 이쁘다 고
# 리뷰 내용입니다:
# 재미있을거 같아요 그래픽 좋고 캐릭터도 이쁘고
#
# Review 2: 가다 주다 모르다 게임 그래픽 며 캐릭터 아이템 지 시스템 잘 구축 되다 고 슈트 갈아입다 으면서 다양 킬 접다 하다 최고 장점 별 고 ^^ 정말 감사 하다 게임 만들다 어서 깊다 노고 진심 느끼다 앞 더 번창하다 ^^
# 리뷰 내용입니다:
# 시간 가는줄 모르는 게임입니다~!~그래픽이며 캐릭 아이템 여러가지 시스템으로 잘 구축이되어있고 슈트를3개씩이나 갈아입으면서 다양한스킬들을 접할수 있어 최고의 장점입니다!! 별100개드리고싶습니다!!^^ 정말감사합니다 이런게임을 만들어주셔서 깊은노고가 진심으로 느껴집니다 앞으로도 더 번창하세요~!~!^^
#
# Review 3: 그래픽 잘 돌아가다 신기하다 이쁘다 캐릭터 화면 구성 레이아웃 완벽 중독성 재미 글쎄 아직 오랫만 오래 해보다 고 게임 나이스
# 리뷰 내용입니다:
# 쩌는 그래픽 잘돌아가는게 신기하다. 이쁜 캐릭터와 화면 구성 레이아웃이 완벽 ㅎ 중독성 있는 재미는 글쎄, 아직 ㅎ 하지만 오랫만에 오래 해보고 싶은 게임 나이스
#
# Review 4: 캐릭터 이쁘다 고 그래픽 너무 좋다 최고
# 리뷰 내용입니다:
# 케릭도 이쁘고 그래픽도 넘~좋아요 최고!!
#
# Review 5: ㅋㅋ 별 ㅋㅋ 캐릭터 입다 움직이다 좋다 ㅋㅋ 게임 미래 지향 잘 만들다 고 기대되다
# 리뷰 내용입니다:
# ㅋㅋ 별건 아니지만 ㅋㅋ 캐릭터입움직이는거 좋네요 ㅋㅋ 겜도 미래지향적으로 잘 만든거같고 기대됩니다
#
# Review 6: 물다 라 어렵다 생각하다 꾸미다 캐릭터 움직이다 다 니 퀘스트 통하다 익숙하다 면서 재밌다
# 리뷰 내용입니다:
# SF물이라 어려울거라 생각했는데:)내가 꾸민 캐릭터를 움직이다보니 퀘스트통해 익숙해지면서 재밋어요
#
# Review 7: 주 캐릭터 전환하다 설정 괜찮다 그래픽 좋다 과금 해보다 중인 막 시작하다 아서 과금 하다 을지 모르다
# 리뷰 내용입니다:
# 주케릭을 전환한다는 설정도 나름 괜찬음.그래픽 좋음. 일단.무과금으로 해보는 중인데..막.시작해서 어디까지 무과금으로 할수있을진 모르지만..일단 ㄱㄱ
#
# Review 8: 그래픽 좋다 고 좋다 커스터마이징 창 하다 인 게임 색감 선명도 너무 다르다 자다 ㅠㅠ ㅠ 아예 캐릭터 되다 ㅠ 초반 정도 커스터마이징 자유롭다 게 꿀 으면 좋다
# 리뷰 내용입니다:
# 일단 그래픽도 좋고..좋은데.. 커마 창에서 한거랑 인게임이랑 색감, 선명도가 너무 다르자나요ㅠㅠㅠ아예 다른캐릭됨ㅠ 초반1~2일정도는 커마 자유롭게 바꿀수있으면 좋겠어요..
#
# Review 9: 해보다 니 캐릭터 별로 고 재미 없다 어서
# 리뷰 내용입니다:
# 해보니 캐릭터도 별로고 재미가 없어서
#
# Review 10: 하다 다 면 데스 티 니 게임 이랑 거지 캐릭터 직업 명 하다 고 그래픽 지도 다 완전 ㄴ데 게임 퀘스트 하다 긴장감 스릴 없다 어서 다행 다행 ㄴ데
# 리뷰 내용입니다:
# 하다보면 데스티니 가디언즈 게임 이랑 같은거지 캐릭직업 명 하고 그래픽 지도 다 완전 비슷한데 그래도 이겜은 퀘스트 할때 긴장감 과 스릴은 없어서 다행이긴 다행 인데
#
#
# Keyword 5: 난이도
# Review 1: 커스터마이징 기능 생각 자세하다 별 근데 움직임 스킬 연계 모션 끊기다 느낌 고 대시 회피 못쓰다 쿨타임 그냥 처맞다 으면서 거나 멀리서 아쉽다 고 논 타겟 팅 라 그렇다 ㄴ지 모르다 아도 스킬 중구난방 뛰다 들다 면 남 잡다 몬스터 건들다 고 지 은데 스킬 쓰다 면 잡다 몬스터 고 새롭다 몬스터 타겟 팅 되다 느낌 퀘스트 더 많이 잡다 ^^ 스토리 그냥저냥 느낌 들다 삭감
# 리뷰 내용입니다:
# 커마기능이 생각보다 자세함(이걸로 별4개). 근데.., 움직임이 스킬연계 모션이 조금 끊기는 느낌이고, 대쉬/회피가 2번밖에 못쓰는게(쿨타임 길다, 그냥 처맞으면서 하거나 멀리서 때림) 조금 아쉽고, 논타겟팅이라 그런지는 몰라도...스킬이 중구난방으로 뛴다. 예를들면 남이 잡는 몬스터를 건들고 싶지않은데 스킬쓰면 잡던몬스터말고 새로운 몬스터로 타겟팅되는 느낌(?) 퀘스트보다 더 많이 잡는^^; 스토리는... 그냥저냥 딱 sf라는 느낌만 듦(별 1개 삭감).
#
# Review 2: 그래픽 게임 자체 매력적 ㄴ데 게임 라 아쉽다 이것다 돈 되다 니까 게임 사들이다 다 이렇게 만들다 ㅠㅠ 아쉽다 매력적 요소 아서 좋다 은데 금방 질리다
# 리뷰 내용입니다:
# 그래픽, 게임 자체는 매력적인데 린라이크류 게임이라 아쉽네요~ 이게 돈이 되니까 게임사들이 다 이렇게 만드는 거겠죠 ㅠㅠ 아쉽네요...!! 그래도 매력적인 요소들은 있는 것 같아서 좋은데 저는 금방 질리네요~
#
# Review 3: 물다 라 어렵다 생각하다 꾸미다 캐릭터 움직이다 다 니 퀘스트 통하다 익숙하다 면서 재밌다
# 리뷰 내용입니다:
# SF물이라 어려울거라 생각했는데:)내가 꾸민 캐릭터를 움직이다보니 퀘스트통해 익숙해지면서 재밋어요
#
# Review 4: 근래 해보다 타격감 좋다 아직 초반 라 그렇다 ㄴ지 게임 이해도 낮다 그렇다 ㄴ지 어렵다 듯 느낌 의상 다양 예쁘다
# 리뷰 내용입니다:
# 근래 해본것중 타격감이 좋네요. 아직 초반이라그런지 게임 이해도가 낮아서그런지 좀 어려운듯한 느낌이 있음. 의상이 다양하고 예쁨.
#
# Review 5: 정말 취향 취향 긴하다 게임 편파 없이 좋다 요즘 게임 핵 과금 러 생각하다 게임 과금 없이 투자하다 면 어렵다 게임 겔 렉 울트라 정도 되다 어야 최고 사양 즐기다 수 발열 없다
# 리뷰 내용입니다:
# 정말 잘만들었습니닺 취향은 취향이긴하지만 게임성은 편파없이 좋습니다 요즘게임은 핵과금러만 생각하는대 이겜은 과금없이도 시간만 투자하면 어려운게임이 아닌거같내요 그리고 겔렉시 울트라 s21정도 되야 최고사양으로 즐길수있습니다 발열없습니다
#
# Review 6: 그래픽 타격감 손쉽다 사냥 만족
# 리뷰 내용입니다:
# 그래픽 타격감 손쉬운 사냥 만족
#
# Review 7: 그래픽 스토리 정말 좋다 은데 많이 낮다 고 과금 너무 유도 하다 아서 아쉽다 뽑다 기권 주다 어도 좋다 으 안 나오다 광고 보다 고 재미있다 아서 는데 계속 하다 되다 ㄹ지 의문
# 리뷰 내용입니다:
# 그래픽이나 스토리는 정말 좋은데 드랍률도 많이 낮고 과금을 너무 유도 하시는 것 같아서 아쉽습니다. 뽑기권을 줘도 좋으거는 하나도 안나오네요 광고 보고 재밌을 것 같아서 했는데... 계속 해야될지.. 의문입니다.
#
# Review 8: 어렵다 그래픽 좋다
# 리뷰 내용입니다:
# 조금 어렵네요 그래도 그래픽은 좋네요
#
# Review 9: 폰 심하다 그래픽 완성도 높지다 그만큼 폰 견디다 쉽다 아서 아쉬움 잦다 튕기다 짜증 나다
# 리뷰 내용입니다:
# 폰 버벅거림,튕김증상 심함. 그래픽 완성도 는 높지만. 그만큼 폰이 견디기 쉽지않아서. 아쉬움..잦은 튕김 이 조금 짜증남
#
# Review 10: 아직 초반 재미있다 게 잘하다 고 더 두다 고 알 그렇게 어렵다 없이 쉽다 게 게임 알리다 고
# 리뷰 내용입니다:
# 아직 초반이지만 재미있게 잘하고 있습니다 더 두고봐야 알겠지만 그렇게 어려운것도 없이 누구나 쉽게 할수 있는 게임 임을 알려 주고 싶네요
#
#
# Keyword 1: 최적화
# Review 1: 최적화 기종 램 폰 게임 모드 켜다 핸드폰 버티다 폰 게임 맞다 정도 요구 사양 높다 빠르다 발열 이로 인하다 성능 저하 폰 폭발 일어나다 짙다 노가다 특정 몹 마리 잡다 도감 작 가능하다 메이플 도감 작다 느낌 라 보다 면 되다 자동사 가능하다 폰 켜다 상당히 증가하다 며 위 문제 폰 갈리다 나가다 도감 재화 능력 업 글 되다 다 니 더욱 문제 되다 ㄴ다 재료 자동 없다 자동사 존재 재료 수급 자동 없다 본인 못 찾다 고 가능성 으나 제작 재료 수급 대하다 아서 불편 하다 부분 현재 정도 플레이 하다 며 느끼다 며 그래픽 타격감 액션 부분 맵 배경 구성 잘 갖추다 허나 최적화 문제 게임 하다 매우 부담스럽다 게 느끼다 ㄴ다
# 리뷰 내용입니다:
# 1.최적화 (현 기종 23+) / 램 12기가 이상 폰이 아닌이상 게임모드를 켜야 겨우 핸드폰이 버틴다. 폰겜이 맞나 싶을정도로 요구사양이 높다. 빠른 발열과 이로인한 성능저하가 곂치면 폰이 폭발이 곧 일어날거 같다. 2. 짙은 노가다성 / 특정 몹을 몇십마리 이상 잡아야 도감작이 가능하다. 메이플 도감작 느낌이라 보면된다. 자동사냥이 가능하나 폰을 켜두는 시간이 상당히 증가하며 이는 위의 문제와 곂치면 폰이 갈려나간다. 도감의 재화가 능력치 업글이 되다보니 더욱 문제가 된다. 3. 재료 파밍 자동이 없다. / 자동사냥만 존재하고 재료수급의 자동이 없다. 본인이 못찾고 있는 가능성도 있으나 이는 제작재료 수급에 대해서 조금 불편한 부분이다. // 현재 1주일 정도 플레이하며 느낀 것이며 그래픽, 타격감 등 액션쪽의 부분과 맵 배경의 구성 등은 잘 갖추어져 있다. 허나 이 모든것이 최적화 문제로 게임이 하기가 매우 부담스럽게 느껴진다.
#
# Review 2: 최적화 잘 안 되다 ㄴ지 하다 면 발열 심하다 면서 렉 심하다 게 걸리다 폰 튕기다 폰 ㄴ데 가끔 게임 팅 기다 ㄴ다 메인 퀘스트 난이도 장난 그렇다 다고 렙업 빠르다 지 고 경험 수급 좋다 지 다 노가다 아주 아주 아주 많이 필요하다 수트 얻다 많이 어렵다 현질 하다 지 낮다 등급 수트 나오다 ㄴ다 메인 퀘스트 ㄴ지 마르다 ㄴ지 ㅋㅋ 무조건 현질 하다 그나마 가능하다 과금 레벨 넘어가다 면서 많이 힘들다 메인 퀘스트 보스 몹 난이도 낮추다 든지 경험 수급 높이다 든지 수트 수급 높이다 든지 다양 하다 방법 마련하다 이러다 면 유저 다 떨어지다 나가다
# 리뷰 내용입니다:
# 최적화 잘 안 된 건지 1~2시간 하면 발열 심해지면서 렉이 심하게 걸림. 내 폰이 팅기는 폰이 아닌데도 가끔은 게임이 팅긴다. 그리고 메인퀘 난이도가 장난아니다. 그렇다고 렙업이 빠르지도 않고 경험치 수급이 좋지도 않다. 노가다가 아주 아주 아주 많이 필요하다. 또 수트 얻는 거에도 많이 어렵다. 현질을 하지 않는 이상 거의 B급 낮은 등급의 수트만 나온다. 이건 뭐 메인퀘를 밀라는 것인지 말라는 것인지... ㅋㅋ 무조건 현질을 해야 그나마 가능하다. 나같은 무과금은 렙 30이 넘어가면서는 많이 힘들어진다. 메인퀘 보스몹들 난이도를 낮추든지 경험치 수급을 높이든지 수트 수급을 높이든지 다양한 방법을 마련해야한다. 이러면 유저들 다 떨어져나감.
#
# Review 3: 플레이 기기 탭 기본 부족 하다 점 최적화 필요 사운드 끊기다 개선 필요 아직 최적화 덜 되다 는지 그래픽 설정 상 표시 하다 는데 발열 많이 심하다 무겁다 게임 돌리다 성능 좋다 다고 못하다 발열 심하다 하다 ㅂ니다 간헐적 사운드 끊기다 문제 페리오 조합 레이저 바라다 쿠 마찬가지 처음 발열 문제 ㄴ가 는데 쿨러 발열 식히다 고 는데 동일하다 캐릭터 시야 전환 안되다 현상 태블릿 필름 문제 맞다 교체하다 니까 정상적 되다 너무 쓰다 소리 하다 는데 캐릭터 외형 커스텀 기능 충분히 잘 만들다 고 재미있다 장르 원래 지루하다 는데 재미있다
# 리뷰 내용입니다:
# 플레이 기기: 갤럭시 탭 S8 기본(WiFi) 부족한 점: 최적화 필요. 사운드 끊김 개선 필요 --아직 최적화가 덜 됐는지 그래픽 설정을 중, 중, 하, 하, 하, 하, 상, 60, ON, 0, ON, ON, 나만 표시, 10명으로 했는데 발열이 많이 심하네요. S8이 무거운 게임을 돌리기에 성능이 좋다고는 못하지만 발열이 심하긴 합니다. --간헐적으로 사운드가 끊기는 문제는 simgot ew100와 페리오딕 로듐/아즈라 A100의 조합과 레이저 바라쿠다 X도 마찬가지네요. 처음에는 발열 문제인가 싶었는데 쿨러로 발열을 식히고 있는데도 동일하네요. --케릭터 시야 전환 안되는 현상은 태블릿 필름 문제가 맞네요. 교체하니까 정상적으로 됩니다. --너무 쓴 소리만 했는데 캐릭터 외형 커스텀 기능등 충분히 잘 만들었고 재밌네요. rpg 장르가 원래 지루했는데 재밌습니다
#
# Review 4: 그래픽 사양 최하 운영하다 아도 렉 심하다 며 배터리 소모 빠르다 발열 엄청 심하다 아서 충전 상태 게임 돌리다 지 추천하다 온도 상승 심하다 안전 충전 중단되다 며 스마트폰 기능 마비되다 안전 기능 저하되다 면 폭발 위험 도 안전 정도 플레이 하다 추전 하다
# 리뷰 내용입니다:
# 그래픽 사양을 최하로 운영하여도 렉이 심하며 배터리 소모가 빠릅니다. 발열이 엄청 심해서 충전상태에서 게임을 돌리지 않는걸 추천합니다. 온도 상승이 심하여 안전상 충전도 중단되며 스마트폰의 모든 기능이 마비됩니다. 안전기능이 저하되면 폭발 위험도 있을거 같습니다. 안전상 20분 정도만 플레이 하는 것을 추전합니다.
#
# Review 5: 다 좋다 은데 발열 장난 발열 게임 자동 종료 하다 ㅂ니다 국내 모바일 게임 사양 높다 다 돌리다 어도 발열 종료되다 게임 없다 는데 처음
# 리뷰 내용입니다:
# 다 좋은데 발열 장난 아니네요. 폴드3에서 발열로 게임을 자동종료 합니다. 국내 모바일게임 사양 높은것들 다 돌려도 발열로 종료되는 게임은 없었는데 아레스가 처음입니다.
#
# Review 6: 폰 게임 하다 버겁다 게임 노트 게임 하다 고 으나 사양 너무 높다 게임 모드 그래픽 설정 하루 맞추다 놓다 아도 폰 과도 하다 발열 쓰다 링 걸리다 성능 제한 걸리다 서버 되다 상태 수시로 필드 하다 면 입장 불가 메세지 나오다 전반적 최적화 필요 하다 상태
# 리뷰 내용입니다:
# 폰으로 겜하기에는 버거운 게임 ......노트 20으로 겜을 하고 있으나 사양이 너무 높아 게임모드 및 그래픽설정을 하로 맞춰놔도 폰이 과도한 발열로 쓰로들링이 걸려 성능 제한 걸림 서버 안정화도 않된상태 수시로 필드가려하면 입장불가 메세지 나옴.. 전반적인 최적화가 필요한 상태......
#
# Review 7: 반열 너무 심하다 고 테블릿 라이트 최적화 엉망 고 게임 하다 라 ㄴ지 마르다 ㄴ지 고사 향 게임 멀쩡하다 게 잘 되다 운영자 게임 접다 답변 잘 읽다 근데 원하다 답변 게임 접다 을지 물다 모바일 게임 최적화 정도 면 만들다 지 말다 진짜 하루 튕기다 고 접속하다 최신 폰 바꾸다 고 게임 하다 소 최신 폰 면 게임 못 받다 게 막다 두다 어야 생각하다 ㄹ수록 열받다 사용 가능 하다 기기 명 라도 따로 공지하다
# 리뷰 내용입니다:
# 갤럭시 N9는 반열이 너무 심하고 테블릿 S6 라이트는 최적화 엉망이고 게임을 하라는건지 말라는건지 고사향 게임은 멀쩡하게 잘되는데...운영자님 게임 접을까요? 답변 잘읽었습니다 근데 제가 원하는 답변은 아니네요 게임을 접을지 물어 봤는데요 모바일 게임 최적화가 이정도면 만들지 말아야죠 진짜 하루에 몇번이나 팅기고 접속해야 하나요? 최신폰으로 바꾸고 게임하라는 소린가요? 최신폰 아니면 게임 못받게 막아둬야죠 생각할수록 열받네...사용 가능한 기기명이라도 따로 공지해 두세요
#
# Review 8: 게임 자체 재미있다 맞다 고 고 많다 고 게임 나오다 지 알다 되다 ㄴ지라 이벤트 많다 고 점검 보상 괜찮다 한데 사람 말하다 뽑다 확률 이리하다 다 거두절미 하다 고 게임 장점 씹다 진짜 최적화 쓰레기 진짜 평가 최적화 잘 되다 다고 해 놓다 개구 최적화 안되다 니까 발열 미치다 고 렉 말 고 없다 고 끊기다 장난 게임 그래픽 사양 설정 하루 맞추다 고 글씨 깨지다 어서 안보 빠르다 시일 내 최적화 문제 해결하다 ㄴ지 궁금하다 이렇게 사양 높다 고 최적화 망하다 게임 내놓다 면 앱 플레이어 사용 막다 놓다 는지
# 리뷰 내용입니다:
# 게임 자체는 재밌는게 맞고 할것고 많고 지금 게임 나온지 얼마 안된지라 이벤트도 많고 점검 보상도 괜찮긴 한데 다른 사람들이 말하는 뽑기 확률 이런거 다 거두절미 하고 이 게임의 모든 장점 씹어먹을 만큼 진짜 최적화가 쓰레기에요 진짜 다른 평가에 최적화 잘 되어있다고 해놓은건 개구라.. 최적화 안되니까 발열 미쳤고 렉은 말할 것고 없고 끊김 장난 아님. (게임 그래픽 사양 설정에서 전부 하로 맞춰놓고 해도 그게 그거임 ㄹㅇ 글씨도 깨져서 안보임) 빠른 시일 내에 최적화 문제를 해결할건지 궁금하네요. 그리고 이렇게 사양 높고 최적화 개망한 게임 내놓을거면 앱플레이어 사용은 왜 막아놓으셨는지..?
#
# Review 9: 재미 액션 타격감 좋다 캐릭터 키 어깨 넓이 조절 좋다 플립 발열 심하다 튕기다 몬스터 마리 잡다 너무 많다 옛날 이렇게 잡다 관두다 자동 기능 어서 좋다 ㄴ가 계속 노가다 하다 느낌 무기 승급하다 다가 실패하다 면 무기 아예 파괴 되다 하다 ㄴ다고 는 두다 단계 이드 고 아예 없다 다시 만들다 고 공력 낮다 고 노가다 하다 채팅 창 힘들다 고 불편하다 배경 계속 똑같다 도시 고 무릉도원 곳 고 폐허 고 더 다양하다 으면 좋다
# 리뷰 내용입니다:
# 재미는 있음 액션 타격감 좋음. 캐릭터 키, 어깨넓이 조절 좋음. 플립4. 발열심함.튕김. 몬스터를 50,80,120, 마리 잡는게 너무 많음.... 옛날 테라도 이렇게 잡다가 관뒀는데..이건 그래도 자동기능이 있어서 좋지만 뭔가 계속 노가다 하는 느낌. 무기를 승급하다가 실패하면 무기가 아예파괴됨.. 한단계 두단계 다운그래이드도 아니고 아예 없어짐... 그럼 다시 만들어야하고 공력 낮아지고.. 또 노가다해야하고... 채팅창이 보기가 힘들고 불편함. 배경이 계속 똑같음. 도시도 있고 무릉도원같은 곳도있고 폐허도 있고 더 다양했으면 좋았을 것 같음.
#
# Review 10: 게임 라 PC 주 목적 되다 어서 나오다 전 모바일 즐기다 고 기대 많이 하다 는데 핸드폰 어렵다 컨트롤 핸드폰 최적화 안되다 모습 핸드폰 무리 없이 진행하다 게 최적화 빨리 하다
# 리뷰 내용입니다:
# 이건 헨드폰 게임이 아니라 pc로 주 목적이 되서 나온것 같네요 전 모바일로 즐기고 싶어 기대를 많이 했는데 핸드폰으로는 어려운 컨트롤과 핸드폰은 최적화가 안된 모습입니다 핸드폰도 무리없이 진행할수있게 최적화를 빨리 해주십쇼
#
#
# Keyword 2: 렉
# Review 1: 렉 심하다 고 자주 그래픽 최대 내려놓다 고 게임 하다 면 그나마 괜찮다 은데 그래픽 최상 하다 솔직히 그닥 좋다 느낌 없다 어서 그러다 려니 ㅂ니다 현질 유도 사전 예약 보상 너무 부실하다 마지막 레벨업 너무 느리다 고 퀘스트 사냥 라 지루하다 하다 고 접다
# 리뷰 내용입니다:
# 일단 첫번째로 렉이 심하고 자주 튕깁니다 그래픽을 최대로 내려놓고 겜하면 그나마 괜찮은데 그래픽 최상으로 해도 솔직히 그닥 좋다는 느낌은 없어서 그러려니 합니다 두번째로는 현질유도와 사전예약 보상이 너무 부실하다는것.. 마지막은 레벨업이 너무느리고 퀘스트가 전부 사냥뿐이라 지루합니다 2시간 하고 접었네요
#
# Review 2: 최적화 잘 안 되다 ㄴ지 하다 면 발열 심하다 면서 렉 심하다 게 걸리다 폰 튕기다 폰 ㄴ데 가끔 게임 팅 기다 ㄴ다 메인 퀘스트 난이도 장난 그렇다 다고 렙업 빠르다 지 고 경험 수급 좋다 지 다 노가다 아주 아주 아주 많이 필요하다 수트 얻다 많이 어렵다 현질 하다 지 낮다 등급 수트 나오다 ㄴ다 메인 퀘스트 ㄴ지 마르다 ㄴ지 ㅋㅋ 무조건 현질 하다 그나마 가능하다 과금 레벨 넘어가다 면서 많이 힘들다 메인 퀘스트 보스 몹 난이도 낮추다 든지 경험 수급 높이다 든지 수트 수급 높이다 든지 다양 하다 방법 마련하다 이러다 면 유저 다 떨어지다 나가다
# 리뷰 내용입니다:
# 최적화 잘 안 된 건지 1~2시간 하면 발열 심해지면서 렉이 심하게 걸림. 내 폰이 팅기는 폰이 아닌데도 가끔은 게임이 팅긴다. 그리고 메인퀘 난이도가 장난아니다. 그렇다고 렙업이 빠르지도 않고 경험치 수급이 좋지도 않다. 노가다가 아주 아주 아주 많이 필요하다. 또 수트 얻는 거에도 많이 어렵다. 현질을 하지 않는 이상 거의 B급 낮은 등급의 수트만 나온다. 이건 뭐 메인퀘를 밀라는 것인지 말라는 것인지... ㅋㅋ 무조건 현질을 해야 그나마 가능하다. 나같은 무과금은 렙 30이 넘어가면서는 많이 힘들어진다. 메인퀘 보스몹들 난이도를 낮추든지 경험치 수급을 높이든지 수트 수급을 높이든지 다양한 방법을 마련해야한다. 이러면 유저들 다 떨어져나감.
#
# Review 3: 그래픽 사양 최하 운영하다 아도 렉 심하다 며 배터리 소모 빠르다 발열 엄청 심하다 아서 충전 상태 게임 돌리다 지 추천하다 온도 상승 심하다 안전 충전 중단되다 며 스마트폰 기능 마비되다 안전 기능 저하되다 면 폭발 위험 도 안전 정도 플레이 하다 추전 하다
# 리뷰 내용입니다:
# 그래픽 사양을 최하로 운영하여도 렉이 심하며 배터리 소모가 빠릅니다. 발열이 엄청 심해서 충전상태에서 게임을 돌리지 않는걸 추천합니다. 온도 상승이 심하여 안전상 충전도 중단되며 스마트폰의 모든 기능이 마비됩니다. 안전기능이 저하되면 폭발 위험도 있을거 같습니다. 안전상 20분 정도만 플레이 하는 것을 추전합니다.
#
# Review 4: 자다 돌아가다 는지 확인 점하다 고 욕하다 든 내기 줄다 개다 울트라 쓰다 그래픽 상 하다 면 잔렉 고 중간 정도 설정하다 면 부드럽다 게 잘 돌아가다 모발 게임 자체 용량 최상 돌리다 수 없다 ㅋㅋ 바라다 바래다 PC 버전 하다 하다 수동 카운터 회피 정말 재밌다 ㅋㅋ PC 하다 참고
# 리뷰 내용입니다:
# 각자 자기 핸폰에 돌아가는지 확인점하고 욕하든 해. 내기준 갤22.울트라 1024메가씀 그래픽 상옵하면 잔렉있고 중간정도 설정하면 부드럽게 잘돌아감. 모발겜자체 용량이 6기가임 최상풀옵으로 돌릴수있는 드폰이는 몇 없음ㅋㅋ 바랄껄바래. pc버전 해봐 두번해라 수동 카운터 회피가 정말 재밋더라ㅋㅋ pc는 20기가용량필요함 참고하셈.
#
# Review 5: 게임 자체 재미있다 맞다 고 고 많다 고 게임 나오다 지 알다 되다 ㄴ지라 이벤트 많다 고 점검 보상 괜찮다 한데 사람 말하다 뽑다 확률 이리하다 다 거두절미 하다 고 게임 장점 씹다 진짜 최적화 쓰레기 진짜 평가 최적화 잘 되다 다고 해 놓다 개구 최적화 안되다 니까 발열 미치다 고 렉 말 고 없다 고 끊기다 장난 게임 그래픽 사양 설정 하루 맞추다 고 글씨 깨지다 어서 안보 빠르다 시일 내 최적화 문제 해결하다 ㄴ지 궁금하다 이렇게 사양 높다 고 최적화 망하다 게임 내놓다 면 앱 플레이어 사용 막다 놓다 는지
# 리뷰 내용입니다:
# 게임 자체는 재밌는게 맞고 할것고 많고 지금 게임 나온지 얼마 안된지라 이벤트도 많고 점검 보상도 괜찮긴 한데 다른 사람들이 말하는 뽑기 확률 이런거 다 거두절미 하고 이 게임의 모든 장점 씹어먹을 만큼 진짜 최적화가 쓰레기에요 진짜 다른 평가에 최적화 잘 되어있다고 해놓은건 개구라.. 최적화 안되니까 발열 미쳤고 렉은 말할 것고 없고 끊김 장난 아님. (게임 그래픽 사양 설정에서 전부 하로 맞춰놓고 해도 그게 그거임 ㄹㅇ 글씨도 깨져서 안보임) 빠른 시일 내에 최적화 문제를 해결할건지 궁금하네요. 그리고 이렇게 사양 높고 최적화 개망한 게임 내놓을거면 앱플레이어 사용은 왜 막아놓으셨는지..?
#
# Review 6: 플립 ㄴ데 렉 너무 심하다 고 핸드폰 터지다 직전 뜨겁다 뭐에 대하다 설명도 그닥 없다 고 렙업 하다 면 ㄹ수록 퀘스트 하다 면 ㄹ수록 너무 벽 느끼다 정도 몬스터 아프다 잡다 몹 피 쭉쭉 빠지다 고 스펙 업 하다 설명 좋다 고 초기 모르다 아서 충전하다 아서 사다 사다 는데 미비 하다 효과 ㅋㅋ
# 리뷰 내용입니다:
# 플립3인데 렉이 너무 심하고 핸드폰 터지기 직전처럼 뜨거워져요 뭐에 대한 설명도 그닥 없고 렙업을 하면 할수록 퀘스트를 하면 할수록 너무 벽 느껴질 정도로 몬스터들이 아픕니다 잡몹한테도 피가 쭉쭉 빠지고;; 스펙업을 할 수 있는 설명들이 있었음 좋았을거고 초기라 뭘 샤얄지 몰라서 5만원만 충전해서 살 거 샀는데도 미비한 효과ㅋㅋ
#
# Review 7: 그래픽 시스템 보다 쉽다 게 잘 며 필드 사냥 사냥 사냥 좋다 시스템 렉 심 하다 유저 들다 많다 아서 하다 레벨 빨리다 고 아이템 쉽다 게 하다 좋다 은데 급 아이템 나오다 쉽다 재료 구하다 쉽다 지 예전 게임 레벨 올리다 쉽다 방어 체력 자동 선택되다 올리다 니까 올리다 어야 하다 ㄹ지 쓰다 어서 좋다 필드 사냥 위주 퀘스트 위주 게임 하다 배경 며 즐기다 면 하다 좋다 힐링 게임 캐릭터 다사용다 하다 어서 크다 장점 라고 생각되다 며 운영자 아이디어 많이 발전 되다 기분 들다 게임 잘 되다 바라다 운영자 폐 트다 퀘스트 걸치다 잡다 으려니 사람 많다 아서 버그 너무 심하다 단축 잡다 게 하다 너무 튕기다 렉 현상 문제 하다
# 리뷰 내용입니다:
# 그래픽과 시스템이 보기쉽게잘되어있으며필드사냥이나 레이드사냥등초보들이사냥하기좋은시스템같습니다. 렉이좀심하지만,유저들접속이많아서 그런듯합니다. 그래도 렙이빨리오르는것같고 아이템들도 쉽게구할수있어 좋은데 A.S급아이템들이 나오기쉽지않네요. 재료구하기쉽지않은듯 하지만,4일만에 33렙올리수있다니 예전다른게임들은 렙올리기쉽지않았는데요. 방어.체력등 자동으로 선택되어 올리니까! 뭘올려야할지 신경안써서 좋습니다. 필드사냥위주 퀘스트위주로 게임하는 저에게는 배경등보며 즐기면서할수있는 좋은힐링게임 입니다. 캐릭터세종류를 다사용할수있어서 큰장점이라고 생각되며 운영자님들 아이디어가 많이발전된 기분이들었습니다. 아레스게임 잘되길바라겠습니다.운영자님 페네트라퀘 몇십시간걸쳐 잡으려니 사람많아서 버그너무심하네요. 시간을단축시키셔 잡게하던가해야죠. 너무팅기네요. 렉현상 문제인듯합니다.
#
# Review 8: 게임 재미있다 는데 최적화 너무 알다 좋다 렉 너무 심하다 아서 프레임 안 나오다 고 게임 하다 너무 힘 들다 핸드폰 쓰다 고 최적화 문제 개선 하다 면 너무 좋다 모바일 게임 ㄴ데 PC 플레이 하다 판 제발 개선 부탁 드리다 제발
# 리뷰 내용입니다:
# 게임은 재밌는데 최적화가 너무 안좋네요 렉이 너무 심해서 프레임도 안나오고 게임 하기 너무 힘드네요 핸드폰은 s21+ 쓰고 있습니다 최적화 문제만 개선좀 해주시면 너무좋을꺼 같아요 모바일 게임인데 pc로 플레이 해야 할판입니다!! 제발 개선좀 부탁드릴께요 제발요!!!
#
# Review 9: 슈트 낮다 등급 면 당연히 사용 안 하다 낮다 슈트 이쁘다 게 많다 아서 착용하다 좋다 스킬 강화 확률 게임 비교하다 아도 준수 한편 하다 게임 계속 하다 되다 ㅎㅎ 컴터 다운 받다 실행하다 아서 는데 렉 가끔 생기다 안 생기다 게끔 조치 내리다 면 재미있다 게 게임 즐기다 거
# 리뷰 내용입니다:
# 슈트가 낮은 등급이면 당연히 사용은 안하겠지만 낮은 슈트중에서도 이쁜게 많아서 그걸 착용할수 있어 좋더라구요 스킬 드랍율이나 강화확률은 뭐.. 다른게임이랑 비교해도 준수한편이긴 한거 같아여 우선 겜을 계속 해봐야 될듯해여ㅎㅎ 그리구..컴터로 다운받아서 실행해서 하는데 렉이.. 가끔 생기더라구요..안생기게끔 조치 내려주시면 재미있게 게임 즐길거 같아요~~
#
# Review 10: 게임 실행 화면 움직임 끊기다 사양 높다 게임 매끄럽다 게 화면 돌아가다 는데 게임 처음 라 당황스럽다 좋아하다 는데 렉 마냥 화면 움직이다 끊기다 니 재미 느끼다 없다
# 리뷰 내용입니다:
# 게임 실행시 화면의 움직임이 뚝뚝 끊김. 사양이 훨씬 높은 게임도 매끄럽게 화면이 돌아가는데, 이런 게임은 첨이라 당황스럽네요. sf류를 좋아하는데 렉 있는 것 마냥 화면 움직일 때 뚝뚝 끊기니 재미를 느낄 수가 없어요
#
#
# Keyword 3: 과금
# Review 1: 렉 심하다 고 자주 그래픽 최대 내려놓다 고 게임 하다 면 그나마 괜찮다 은데 그래픽 최상 하다 솔직히 그닥 좋다 느낌 없다 어서 그러다 려니 ㅂ니다 현질 유도 사전 예약 보상 너무 부실하다 마지막 레벨업 너무 느리다 고 퀘스트 사냥 라 지루하다 하다 고 접다
# 리뷰 내용입니다:
# 일단 첫번째로 렉이 심하고 자주 튕깁니다 그래픽을 최대로 내려놓고 겜하면 그나마 괜찮은데 그래픽 최상으로 해도 솔직히 그닥 좋다는 느낌은 없어서 그러려니 합니다 두번째로는 현질유도와 사전예약 보상이 너무 부실하다는것.. 마지막은 레벨업이 너무느리고 퀘스트가 전부 사냥뿐이라 지루합니다 2시간 하고 접었네요
#
# Review 2: 최적화 잘 안 되다 ㄴ지 하다 면 발열 심하다 면서 렉 심하다 게 걸리다 폰 튕기다 폰 ㄴ데 가끔 게임 팅 기다 ㄴ다 메인 퀘스트 난이도 장난 그렇다 다고 렙업 빠르다 지 고 경험 수급 좋다 지 다 노가다 아주 아주 아주 많이 필요하다 수트 얻다 많이 어렵다 현질 하다 지 낮다 등급 수트 나오다 ㄴ다 메인 퀘스트 ㄴ지 마르다 ㄴ지 ㅋㅋ 무조건 현질 하다 그나마 가능하다 과금 레벨 넘어가다 면서 많이 힘들다 메인 퀘스트 보스 몹 난이도 낮추다 든지 경험 수급 높이다 든지 수트 수급 높이다 든지 다양 하다 방법 마련하다 이러다 면 유저 다 떨어지다 나가다
# 리뷰 내용입니다:
# 최적화 잘 안 된 건지 1~2시간 하면 발열 심해지면서 렉이 심하게 걸림. 내 폰이 팅기는 폰이 아닌데도 가끔은 게임이 팅긴다. 그리고 메인퀘 난이도가 장난아니다. 그렇다고 렙업이 빠르지도 않고 경험치 수급이 좋지도 않다. 노가다가 아주 아주 아주 많이 필요하다. 또 수트 얻는 거에도 많이 어렵다. 현질을 하지 않는 이상 거의 B급 낮은 등급의 수트만 나온다. 이건 뭐 메인퀘를 밀라는 것인지 말라는 것인지... ㅋㅋ 무조건 현질을 해야 그나마 가능하다. 나같은 무과금은 렙 30이 넘어가면서는 많이 힘들어진다. 메인퀘 보스몹들 난이도를 낮추든지 경험치 수급을 높이든지 수트 수급을 높이든지 다양한 방법을 마련해야한다. 이러면 유저들 다 떨어져나감.
#
# Review 3: 뽑다 기 확률 너무 알다 좋다 어떻하다 게 돌리다 어도 다 최하 등급 나오다 가끔 나오다 고 과금 하다 게 만들다 려고 작정 하다 기대하다 게임 데 과금 요소 심하다 아서 진짜 제대로 하다 생각 사라지다 경매장 이용도 게임 내의 머니 거 현질 다이아 구매하다 아서 이용하다 진짜 어이없다 일반 게임 좋아하다 사람 적당히 현질 하다 면서 ㄴ데 패키지 가격 진짜 최소 정도 고 다 비싸다 니까 현질 하다 생각 없다 적당히 하다 지
# 리뷰 내용입니다:
# 뽑기확률이 너무 안좋아요... 어떻게 몇번을 돌려도 다 최하등급만 나오죠.. b도 가끔 나오고... 과금을 하게 만들려고 작정을 하셨네요.. 기대했는 게임이데 과금요소가 심해서 진짜 제대로 할 생각이 사라짐... 경매장 이용도 게임내의.머니가 아니거 현질로 다이아 구매해서 이용하는게 진짜 좀 어이없었음.... 일반 게임좋아하는 사람들은 적당히 현질하면서 할텐데 패키지 가격도 진짜 최소 1만원정도고 그 외엔 다 비싸니깐 현질 할 생각이 없어짐... 적당히좀 하지...
#
# Review 4: 전투 스타일 마음 들다 화려 멋지다 빠르다 스토리 라인 별로 고 내용 ㄴ지 잘 모르다 는데 그냥저냥 진행되다 느낌 그러다 다 니 몰입 잘 안 되다 스토리 라인 붕 뜨다 느낌 다 니 콘텐츠 더 집중하다 느낌 현질 유도 곳곳 보이다 정도 현질 필요하다 아직 모르다 전투 스타일 마음 들다 개인적 게임 긍정적 인 게 전투 스타일 아직 벌다 더 하다 살짝 맛 보다 고 접다 느낌
# 리뷰 내용입니다:
# 1. 전투 스타일은 마음에 듭니다. 화려하고 멋지네요. 빠르고요. 2. 다만, 스토리 라인이 별로.. 누가 누구이고 뭔 내용인지 잘 모르는데 그냥저냥 진행되는 느낌. 그러다보니 몰입이 잘 안 됩니다. 3. 스토리 라인이 약간 붕 뜬 느낌이다보니 pvp 콘텐츠에 더 집중하는 느낌. 4. 현질 유도가 곳곳에 보임. 물론 mmorpg인 이상 어느정도 현질은 필요하겠지만 아직 모르겠음. 5. 전투 스타일은 마음에 들지만.. 저는 개인적으로 이 게임의 긍정적인게 딱 전투 스타일 하나였습니다. 6. 아직은 몇번 더 해봐야겠지만.. 살짝 맛만 보고 접을 것 같은 느낌.
#
# Review 5: 게임 부 는데 살다 다 살다 이렇게 돈 공중분해 느낌 들다 는 게임 처음 가챠 게임 하루 이틀 하다 고 모바일 게임 돈 프로 과금 러 어도 과금 하다 다 고생 각하 보통 사면 이제 위로차 원의 보상 후하다 게 뿌리다 반 면 게임 확률 극악 고 대체 치다 쏟다 등급 슈트 탈것 오퍼레이터 얻다 ㄴ지 앞 깜깜하다 게임 서다 자동차 게임 가량 부 는데 얻다 다 고 이외 보상 두둑 끊임없이 자그마하다 노력 보상 주어지다 쉬다 틈 없이 즐기다 는데 게임 게임 ㄴ데 우째 게임 못하다 ㄴ지 치다 부 는데 스토리 막히다 고 이것다 실화 ㄴ지 도무지 믿기다 지가 고 하다 면 하다 ㄹ수록 느끼다 진짜 악랄하다 다라고 끼다 고 출시 전 담당자 나오다 아서 다르다 어쩌다 해 고 ㅋㅋ 진짜 개살 벌다 하다 ㅋㅋ 정도 돈 환장하다 밖 생각 안 들다 떨어지다 어서 돈 부 아깝다 어서 피눈물 이남 노예 되다
# 리뷰 내용입니다:
# 이게임에 100만원 부었는데 살다살다 이렇게 돈을 공중분해시킨 느낌이 드는겜은 처음임;; 가챠겜 하루이틀하는것도아니고 모바일겜에 돈을 프로과금러는 아니여도 과금을 나름 했다고생각하는데, 보통 11만원짜리 사면 이제 다른 위로차원의 보상들도 같이 후하게 뿌려주는반면 이겜은 확률도 극악이고 대체 얼마를 쳐 쏟아야 R등급이상 슈트,탈것,오퍼레이터를 얻는건지 앞이 깜깜함. 이겜하기전 에X스레이서라는 자동차 게임에도 100만원가량 부었는데 결국 얻을거 다 었었고 이외에도 보상이 두둑하고 끊임없이 자그마한 노력에따른 보상이 주어져 쉴틈없이 즐겼었는데 그겜은 중국겜인데 우째 중국겜보다도 못한지;; 100만원 쳐부었는데도 스토리막히고 이게 실화인지 도무지 믿기지가않고 하면할수록 느끼는게 진짜 악랄하다라고밖에 안느껴지고 출시전엔뭐 담당자나와서 이번건 다르다 어쩌구 해놓고ㅋㅋ 진짜 개살벌함ㅋㅋㅋ 이정도로까지 돈에 환장했나밖에 생각이 안든다.. 오만정 떨어져서 돈부은게 아까워서 피눈물이남.. 노예됨
#
# Review 6: 논 타겟 팅 도입하다 면 뭐하다 연출 신경 쓰다 면 뭐하다 총 라고 존재 는데 아군 허허벌판 싸우다 지형 없다 전략 전술 없다 고 자동 돌려놓다 게 되다 지 이러하다 그냥 리니지 하다 지 뭐하다 러 게임 하다 제대로 액션 게임 표방하다 면 확실히 하다 든가 핵 과금 러 잡다 고 신규 유저 잡다 고 고 중도 추구하다 면 이렇게 폭망 하다
# 리뷰 내용입니다:
# 논타겟팅만 도입하면 뭐해. 연출 신경쓰면 뭐해. 총이란 존재가 있는데 적도 아군도 허허벌판에서 싸우네. 지형이랄 게 없어. 전략전술이랄 게 있을수가 없고 그저 자동 돌려놓게 되지. 이럼 그냥 리니지 하지 뭐하러 이 겜 함? 제대로 액션겜 표방할 거면 확실히 하든가. 핵과금러는 잡아야겠고 신규유저도 잡고싶고. 중도를 추구하면 이렇게 폭망 하는거야.
#
# Review 7: 미래 넘다 으면 현질 구간 오다 오픈 대비 퍼 주다 너무 없다 고 뽑다 늘 그렇다 듯 확률
# 리뷰 내용입니다:
# 미래형 오딘 30넘으면 현질구간 옵니다 오픈대비 퍼주는게 너무 없고 뽑기는 늘 그렇듯 확률이 ....BYe~
#
# Review 8: 역시 현질 유도 빠지다 면 안되다 지 메인 퀘스트 진행 안 되다 정도 고 컨트롤 가능하다 이리하다 없다 회피 하다 면 하다 퀘스트 몹 스킬 범위 어마어마 한데 엉망
# 리뷰 내용입니다:
# 역시 현질 유도는 빠지면 안되지! 메인퀘스트 진행이 안될정도고 컨트롤로 가능하겠다? 이런거 없음. 회피를 하면 뭘해 퀘스트 몹 스킬 범위가 어마어마 한데.. 엉망이네...
#
# Review 9: 윽 기대하다 막상 나오다 면 리니지 라이크 게임 ㅋㅋ ㅋㅋ ㅋㅋ 분명 색다르다 게 만들다 고 개발자 명 데리다 곱다 아서 겉 번지르르 하다 게 만들다 고 최적화 안되다 고 그냥 리니지 만들다 고 아서 정도 현질 하다 흑 우 돈 빨아먹다 으면서 마켓 위 달성 라고 면서 탈것 아바타 뿌리다 고 추후 유저 점점 줄어들다 고 뒤늦다 게 공 성전 대규모 이벤트 하다 면서 탈것 아바타 출석 하다 면서 사람 끌다 들이다 어서 유저 돈 빨아먹다 다가 망하다 발전 끼다 ㅋㅋ ㅋㅋ 쪽 팔리다 알다 고 ㅋㅋ ㅋㅋ
# 리뷰 내용입니다:
# 여윽시 기대했지만 막상 나오면 리니지라이크류 게임 ㅋㅋㅋㅋㅋㅋ 분명 색다르게 만들수있었을거고 개발자들도 여러명 데리고와서 겉으로만 번지르르 하게만들고 최적화도 안되고 그냥 리니지같이 만들고나서 1주일정도 현질해주는 흑우들 돈 빨아먹으면서 양대마켓 1위 달성이라고하면서 A급 탈것 아바타 1개씩 뿌리고 추후 유저수 점점 줄어들고 할때 뒤늦게 공성전 대규모 이벤트 하면서 S급 탈것 아바타 1달 출석시 전원제공!! 하면서 사람 또 끌여들여서 유저들 돈 빨아먹다가 망하겠지.. 좀 발전좀하고 바껴라 ㅋㅋㅋㅋㅋ 쪽팔린줄 알고 ㅋㅋㅋㅋㅋ
#
# Review 10: 타워 마을 가다 면 렉 엄청나다 안 게 되다 고 수집 등록하다 려면 무한 로딩 뜨다 어서 계속 팅 김 몇일 안되다 수집 등록 못하다 고 인 베다 도저히 안되다 어서 한가 하다 지역 가다 아서 수집 창 열다 마찬가지 무한 로딩 게임 폰 사양 ㄴ가 메인 폰 깔다 아서 아도 동일 증상 도대체 서버 운영 어떻하다 게 현질 해 가다 면서 하다 고 잇다 는데 수집 등록 못하다 아서 게임 접다 진지하다 게 고민하다 되다 카카오 게임 이제 거르다
# 리뷰 내용입니다:
# 가디언타워 마을가면 랙 엄청나서 안가게되고 수집 등록하려면 무한로딩떠서 계속 팅김. 몇일째 안되서 수집등록못하고 인벤 100퍼되서 도저히 안되겟어서 한가한 지역가서 수집창 열어도 마찬가지 무한로딩.. 겜폰 사양때문인가 싶어 메인폰에 깔아서 해봐도 동일증상 도대체 서버 운영을 어떻게 하는거임?? 현질까지 해가면서 하고잇는데 수집 등록 못해서 게임접을까 진지하게 고민해야 되는게 정상인가요? 카카오게임도 이젠 걸러야겠네
#
#
# Keyword 4: 캐릭터
# Review 1: 플레이 기기 탭 기본 부족 하다 점 최적화 필요 사운드 끊기다 개선 필요 아직 최적화 덜 되다 는지 그래픽 설정 상 표시 하다 는데 발열 많이 심하다 무겁다 게임 돌리다 성능 좋다 다고 못하다 발열 심하다 하다 ㅂ니다 간헐적 사운드 끊기다 문제 페리오 조합 레이저 바라다 쿠 마찬가지 처음 발열 문제 ㄴ가 는데 쿨러 발열 식히다 고 는데 동일하다 캐릭터 시야 전환 안되다 현상 태블릿 필름 문제 맞다 교체하다 니까 정상적 되다 너무 쓰다 소리 하다 는데 캐릭터 외형 커스텀 기능 충분히 잘 만들다 고 재미있다 장르 원래 지루하다 는데 재미있다
# 리뷰 내용입니다:
# 플레이 기기: 갤럭시 탭 S8 기본(WiFi) 부족한 점: 최적화 필요. 사운드 끊김 개선 필요 --아직 최적화가 덜 됐는지 그래픽 설정을 중, 중, 하, 하, 하, 하, 상, 60, ON, 0, ON, ON, 나만 표시, 10명으로 했는데 발열이 많이 심하네요. S8이 무거운 게임을 돌리기에 성능이 좋다고는 못하지만 발열이 심하긴 합니다. --간헐적으로 사운드가 끊기는 문제는 simgot ew100와 페리오딕 로듐/아즈라 A100의 조합과 레이저 바라쿠다 X도 마찬가지네요. 처음에는 발열 문제인가 싶었는데 쿨러로 발열을 식히고 있는데도 동일하네요. --케릭터 시야 전환 안되는 현상은 태블릿 필름 문제가 맞네요. 교체하니까 정상적으로 됩니다. --너무 쓴 소리만 했는데 캐릭터 외형 커스텀 기능등 충분히 잘 만들었고 재밌네요. rpg 장르가 원래 지루했는데 재밌습니다
#
# Review 2: 캐릭터 생성하다 다가 튕기다 대기 다시 기다리다 라는데 튕기다 지하도 고 데이터 잘 터지다 곳 하다 는데 불안정 하다 ㄴ지 모르다
# 리뷰 내용입니다:
# 캐릭터 생성하다가 4번째 튕겨서 대기열 다시 기다리라는데 왜 튕기는거죠? 지하도 아니고 데이터 잘 터지는 곳에서 하는데 뭐가 불안정한건지 모르겠네...
#
# Review 3: 캐릭터 커스터마이징 도중 생성 제한 걸리다 면서 서버 지 너무 노력 무시하다 커스터마이징 시작 하다 시점 캐릭터 생성 되다 처리하다 어야 이제 믿다 고 커스텀 하다 만들다 캐릭터 없다 그냥 캐릭터 만들다 지 말다 까다
# 리뷰 내용입니다:
# 캐릭터 커스터마이징 도중에 생성 제한 걸리면서 서버에서 나가지는 거 너무 노력을 무시하는 거 아닌가요? 커스터마이징 시작한 시점에서 캐릭터 생성 된 걸로 처리해주셔야죠. 이제 뭐 믿고 커스텀 하나요? 한 시간 동안 만들던 캐릭터 없어졌습니다. 그냥 캐릭터 하나도 만들지 말까봐요
#
# Review 4: 사전 다운로드 하다 고 마법사 캐릭터 이쁘다 길래 고르다 고 직업 고르다 헌터 고르다 는데 마법사 되다 어서 바꾸다 려니 꿀 없다 깎다
# 리뷰 내용입니다:
# 사전 다운로드 하고 마법사 캐릭이 이쁘길래 고르고 직업 고르기에 헌터 골랐는데 마법사 되어버려서 바꾸려니 바꿀수도 없네요 그러므로 별 1개 깎았어요.
#
# Review 5: 실망 너무나 화면 어지럽다 고 캐릭터 움직임 화면 이동 매끄럽다 지 고 그냥 양산 게임 다가 그래픽 좋다 덮어놓다 개선하다 점 너무 많다 설정 전투 화면 진동 오프 없다 고 설정 들어가다 면 너무 대충 만들다 게임 만들다 고 얼굴 비추다 면서 칭 하다 고 자다 만들다 는지 모르다 내다 그냥 중간 스토리 멎다 게 만들다 어서 과대 광고 하다 내다 농락 당하 국산 게임 기대다 안 하다 ㅋㅋ
# 리뷰 내용입니다:
# 실망 스럽다 너무나도 화면은 어지럽고 캐릭터 움직임 화면 이동등 매끄럽지도 않고 그냥 중국양산형 게임에 다가 그래픽만 좋게 덮어놓은듯 개선할점 너무 많다 설정에 전투시 화면 진동 온 오프도 없고 설정 들어가보면 너무대충 만들었다 이런 게임 만들어 놓고 얼굴 비추면서 론칭도 하고 머를 잘 만들었는지 모르겠내 그냥 중간 스토리를 멎지게 만들어서 과대 광고 한거내 또 농락 당했네 국산게임 기대도 안했지만 ㅋㅋㅋ
#
# Review 6: 재미 액션 타격감 좋다 캐릭터 키 어깨 넓이 조절 좋다 플립 발열 심하다 튕기다 몬스터 마리 잡다 너무 많다 옛날 이렇게 잡다 관두다 자동 기능 어서 좋다 ㄴ가 계속 노가다 하다 느낌 무기 승급하다 다가 실패하다 면 무기 아예 파괴 되다 하다 ㄴ다고 는 두다 단계 이드 고 아예 없다 다시 만들다 고 공력 낮다 고 노가다 하다 채팅 창 힘들다 고 불편하다 배경 계속 똑같다 도시 고 무릉도원 곳 고 폐허 고 더 다양하다 으면 좋다
# 리뷰 내용입니다:
# 재미는 있음 액션 타격감 좋음. 캐릭터 키, 어깨넓이 조절 좋음. 플립4. 발열심함.튕김. 몬스터를 50,80,120, 마리 잡는게 너무 많음.... 옛날 테라도 이렇게 잡다가 관뒀는데..이건 그래도 자동기능이 있어서 좋지만 뭔가 계속 노가다 하는 느낌. 무기를 승급하다가 실패하면 무기가 아예파괴됨.. 한단계 두단계 다운그래이드도 아니고 아예 없어짐... 그럼 다시 만들어야하고 공력 낮아지고.. 또 노가다해야하고... 채팅창이 보기가 힘들고 불편함. 배경이 계속 똑같음. 도시도 있고 무릉도원같은 곳도있고 폐허도 있고 더 다양했으면 좋았을 것 같음.
#
# Review 7: 튜토리얼 하다 다가 지우다 게임 만들다 말다 그래픽 허접하다 특히 물 표현 너무 심하다 배경 캐릭터 전혀 어울리다 지 색감 고민 아예 알다 하다 오프닝 게임 배경 설명 없다 몰입도 없다 캐릭터 덩치 최대 들다 으니 캐릭터 이질감 생김 덩치 차이 배 정도 일반인 끼다 국산 모바일 게임 미래 보여주다 참담하다
# 리뷰 내용입니다:
# 튜토리얼 하다가 지움... 어찌 게임을 만들다 말았나? 그래픽 허접함, 특히 물 표현 너무 심함. 배경과 케릭터가 전혀 어울리지 않음. 색감 고민은 아예 안한것 같음. 오프닝에 게임 배경설명 없음, 몰입도 없음. 케릭덩치 최대치로 만드니까 다른 케릭들과 이질감 생김. 덩치차이 2배정도.. 일반인에 하승진 껴 있는것 같음. 국산 모바일게임의 현재와 미래를 보여주는것 같아 참담함
#
# Review 8: 아무것 없다 오픈 월드 카카오 스토리 전개 주입식 튜토리얼 매력 없다 아군 캐릭터 초반 들이다 미 결제 창 완벽하다 PC 하다 서버 프레임 덤 고 모바일 발열 진부하다 스토리 꽉꽉 담다
# 리뷰 내용입니다:
# 아무것도 없는 오픈월드랑 카카오식 스토리전개, 주입식 튜토리얼과 매력없는 적, 아군캐릭터 초반부터 들이미는 결제창까지 완벽합니다. PC로 해도 서버 프레임드랍은 덤이고 모바일 발열에 진부한 스토리까지 꽉꽉 담았네요
#
# Review 9: 그래픽 시스템 보다 쉽다 게 잘 며 필드 사냥 사냥 사냥 좋다 시스템 렉 심 하다 유저 들다 많다 아서 하다 레벨 빨리다 고 아이템 쉽다 게 하다 좋다 은데 급 아이템 나오다 쉽다 재료 구하다 쉽다 지 예전 게임 레벨 올리다 쉽다 방어 체력 자동 선택되다 올리다 니까 올리다 어야 하다 ㄹ지 쓰다 어서 좋다 필드 사냥 위주 퀘스트 위주 게임 하다 배경 며 즐기다 면 하다 좋다 힐링 게임 캐릭터 다사용다 하다 어서 크다 장점 라고 생각되다 며 운영자 아이디어 많이 발전 되다 기분 들다 게임 잘 되다 바라다 운영자 폐 트다 퀘스트 걸치다 잡다 으려니 사람 많다 아서 버그 너무 심하다 단축 잡다 게 하다 너무 튕기다 렉 현상 문제 하다
# 리뷰 내용입니다:
# 그래픽과 시스템이 보기쉽게잘되어있으며필드사냥이나 레이드사냥등초보들이사냥하기좋은시스템같습니다. 렉이좀심하지만,유저들접속이많아서 그런듯합니다. 그래도 렙이빨리오르는것같고 아이템들도 쉽게구할수있어 좋은데 A.S급아이템들이 나오기쉽지않네요. 재료구하기쉽지않은듯 하지만,4일만에 33렙올리수있다니 예전다른게임들은 렙올리기쉽지않았는데요. 방어.체력등 자동으로 선택되어 올리니까! 뭘올려야할지 신경안써서 좋습니다. 필드사냥위주 퀘스트위주로 게임하는 저에게는 배경등보며 즐기면서할수있는 좋은힐링게임 입니다. 캐릭터세종류를 다사용할수있어서 큰장점이라고 생각되며 운영자님들 아이디어가 많이발전된 기분이들었습니다. 아레스게임 잘되길바라겠습니다.운영자님 페네트라퀘 몇십시간걸쳐 잡으려니 사람많아서 버그너무심하네요. 시간을단축시키셔 잡게하던가해야죠. 너무팅기네요. 렉현상 문제인듯합니다.
#
# Review 10: 캐릭터 선택 창 들어가다 는데 접속하다 려고 면 계속 튕기다 대체 게임 어떻하다 게 ㄴ지
# 리뷰 내용입니다:
# 캐릭터 선택 창까지는 들어가지는데 접속하려고 하면 계속 튕김. 대체 게임을 어떻게 하라는 건지???
#
#
# Keyword 5: 그래픽
# Review 1: 최적화 기종 램 폰 게임 모드 켜다 핸드폰 버티다 폰 게임 맞다 정도 요구 사양 높다 빠르다 발열 이로 인하다 성능 저하 폰 폭발 일어나다 짙다 노가다 특정 몹 마리 잡다 도감 작 가능하다 메이플 도감 작다 느낌 라 보다 면 되다 자동사 가능하다 폰 켜다 상당히 증가하다 며 위 문제 폰 갈리다 나가다 도감 재화 능력 업 글 되다 다 니 더욱 문제 되다 ㄴ다 재료 자동 없다 자동사 존재 재료 수급 자동 없다 본인 못 찾다 고 가능성 으나 제작 재료 수급 대하다 아서 불편 하다 부분 현재 정도 플레이 하다 며 느끼다 며 그래픽 타격감 액션 부분 맵 배경 구성 잘 갖추다 허나 최적화 문제 게임 하다 매우 부담스럽다 게 느끼다 ㄴ다
# 리뷰 내용입니다:
# 1.최적화 (현 기종 23+) / 램 12기가 이상 폰이 아닌이상 게임모드를 켜야 겨우 핸드폰이 버틴다. 폰겜이 맞나 싶을정도로 요구사양이 높다. 빠른 발열과 이로인한 성능저하가 곂치면 폰이 폭발이 곧 일어날거 같다. 2. 짙은 노가다성 / 특정 몹을 몇십마리 이상 잡아야 도감작이 가능하다. 메이플 도감작 느낌이라 보면된다. 자동사냥이 가능하나 폰을 켜두는 시간이 상당히 증가하며 이는 위의 문제와 곂치면 폰이 갈려나간다. 도감의 재화가 능력치 업글이 되다보니 더욱 문제가 된다. 3. 재료 파밍 자동이 없다. / 자동사냥만 존재하고 재료수급의 자동이 없다. 본인이 못찾고 있는 가능성도 있으나 이는 제작재료 수급에 대해서 조금 불편한 부분이다. // 현재 1주일 정도 플레이하며 느낀 것이며 그래픽, 타격감 등 액션쪽의 부분과 맵 배경의 구성 등은 잘 갖추어져 있다. 허나 이 모든것이 최적화 문제로 게임이 하기가 매우 부담스럽게 느껴진다.
#
# Review 2: 렉 심하다 고 자주 그래픽 최대 내려놓다 고 게임 하다 면 그나마 괜찮다 은데 그래픽 최상 하다 솔직히 그닥 좋다 느낌 없다 어서 그러다 려니 ㅂ니다 현질 유도 사전 예약 보상 너무 부실하다 마지막 레벨업 너무 느리다 고 퀘스트 사냥 라 지루하다 하다 고 접다
# 리뷰 내용입니다:
# 일단 첫번째로 렉이 심하고 자주 튕깁니다 그래픽을 최대로 내려놓고 겜하면 그나마 괜찮은데 그래픽 최상으로 해도 솔직히 그닥 좋다는 느낌은 없어서 그러려니 합니다 두번째로는 현질유도와 사전예약 보상이 너무 부실하다는것.. 마지막은 레벨업이 너무느리고 퀘스트가 전부 사냥뿐이라 지루합니다 2시간 하고 접었네요
#
# Review 3: 플레이 기기 탭 기본 부족 하다 점 최적화 필요 사운드 끊기다 개선 필요 아직 최적화 덜 되다 는지 그래픽 설정 상 표시 하다 는데 발열 많이 심하다 무겁다 게임 돌리다 성능 좋다 다고 못하다 발열 심하다 하다 ㅂ니다 간헐적 사운드 끊기다 문제 페리오 조합 레이저 바라다 쿠 마찬가지 처음 발열 문제 ㄴ가 는데 쿨러 발열 식히다 고 는데 동일하다 캐릭터 시야 전환 안되다 현상 태블릿 필름 문제 맞다 교체하다 니까 정상적 되다 너무 쓰다 소리 하다 는데 캐릭터 외형 커스텀 기능 충분히 잘 만들다 고 재미있다 장르 원래 지루하다 는데 재미있다
# 리뷰 내용입니다:
# 플레이 기기: 갤럭시 탭 S8 기본(WiFi) 부족한 점: 최적화 필요. 사운드 끊김 개선 필요 --아직 최적화가 덜 됐는지 그래픽 설정을 중, 중, 하, 하, 하, 하, 상, 60, ON, 0, ON, ON, 나만 표시, 10명으로 했는데 발열이 많이 심하네요. S8이 무거운 게임을 돌리기에 성능이 좋다고는 못하지만 발열이 심하긴 합니다. --간헐적으로 사운드가 끊기는 문제는 simgot ew100와 페리오딕 로듐/아즈라 A100의 조합과 레이저 바라쿠다 X도 마찬가지네요. 처음에는 발열 문제인가 싶었는데 쿨러로 발열을 식히고 있는데도 동일하네요. --케릭터 시야 전환 안되는 현상은 태블릿 필름 문제가 맞네요. 교체하니까 정상적으로 됩니다. --너무 쓴 소리만 했는데 캐릭터 외형 커스텀 기능등 충분히 잘 만들었고 재밌네요. rpg 장르가 원래 지루했는데 재밌습니다
#
# Review 4: 그래픽 사양 최하 운영하다 아도 렉 심하다 며 배터리 소모 빠르다 발열 엄청 심하다 아서 충전 상태 게임 돌리다 지 추천하다 온도 상승 심하다 안전 충전 중단되다 며 스마트폰 기능 마비되다 안전 기능 저하되다 면 폭발 위험 도 안전 정도 플레이 하다 추전 하다
# 리뷰 내용입니다:
# 그래픽 사양을 최하로 운영하여도 렉이 심하며 배터리 소모가 빠릅니다. 발열이 엄청 심해서 충전상태에서 게임을 돌리지 않는걸 추천합니다. 온도 상승이 심하여 안전상 충전도 중단되며 스마트폰의 모든 기능이 마비됩니다. 안전기능이 저하되면 폭발 위험도 있을거 같습니다. 안전상 20분 정도만 플레이 하는 것을 추전합니다.
#
# Review 5: 자다 돌아가다 는지 확인 점하다 고 욕하다 든 내기 줄다 개다 울트라 쓰다 그래픽 상 하다 면 잔렉 고 중간 정도 설정하다 면 부드럽다 게 잘 돌아가다 모발 게임 자체 용량 최상 돌리다 수 없다 ㅋㅋ 바라다 바래다 PC 버전 하다 하다 수동 카운터 회피 정말 재밌다 ㅋㅋ PC 하다 참고
# 리뷰 내용입니다:
# 각자 자기 핸폰에 돌아가는지 확인점하고 욕하든 해. 내기준 갤22.울트라 1024메가씀 그래픽 상옵하면 잔렉있고 중간정도 설정하면 부드럽게 잘돌아감. 모발겜자체 용량이 6기가임 최상풀옵으로 돌릴수있는 드폰이는 몇 없음ㅋㅋ 바랄껄바래. pc버전 해봐 두번해라 수동 카운터 회피가 정말 재밋더라ㅋㅋ pc는 20기가용량필요함 참고하셈.
#
# Review 6: 실망 너무나 화면 어지럽다 고 캐릭터 움직임 화면 이동 매끄럽다 지 고 그냥 양산 게임 다가 그래픽 좋다 덮어놓다 개선하다 점 너무 많다 설정 전투 화면 진동 오프 없다 고 설정 들어가다 면 너무 대충 만들다 게임 만들다 고 얼굴 비추다 면서 칭 하다 고 자다 만들다 는지 모르다 내다 그냥 중간 스토리 멎다 게 만들다 어서 과대 광고 하다 내다 농락 당하 국산 게임 기대다 안 하다 ㅋㅋ
# 리뷰 내용입니다:
# 실망 스럽다 너무나도 화면은 어지럽고 캐릭터 움직임 화면 이동등 매끄럽지도 않고 그냥 중국양산형 게임에 다가 그래픽만 좋게 덮어놓은듯 개선할점 너무 많다 설정에 전투시 화면 진동 온 오프도 없고 설정 들어가보면 너무대충 만들었다 이런 게임 만들어 놓고 얼굴 비추면서 론칭도 하고 머를 잘 만들었는지 모르겠내 그냥 중간 스토리를 멎지게 만들어서 과대 광고 한거내 또 농락 당했네 국산게임 기대도 안했지만 ㅋㅋㅋ
#
# Review 7: 폰 게임 하다 버겁다 게임 노트 게임 하다 고 으나 사양 너무 높다 게임 모드 그래픽 설정 하루 맞추다 놓다 아도 폰 과도 하다 발열 쓰다 링 걸리다 성능 제한 걸리다 서버 되다 상태 수시로 필드 하다 면 입장 불가 메세지 나오다 전반적 최적화 필요 하다 상태
# 리뷰 내용입니다:
# 폰으로 겜하기에는 버거운 게임 ......노트 20으로 겜을 하고 있으나 사양이 너무 높아 게임모드 및 그래픽설정을 하로 맞춰놔도 폰이 과도한 발열로 쓰로들링이 걸려 성능 제한 걸림 서버 안정화도 않된상태 수시로 필드가려하면 입장불가 메세지 나옴.. 전반적인 최적화가 필요한 상태......
#
# Review 8: 게임 자체 재미있다 맞다 고 고 많다 고 게임 나오다 지 알다 되다 ㄴ지라 이벤트 많다 고 점검 보상 괜찮다 한데 사람 말하다 뽑다 확률 이리하다 다 거두절미 하다 고 게임 장점 씹다 진짜 최적화 쓰레기 진짜 평가 최적화 잘 되다 다고 해 놓다 개구 최적화 안되다 니까 발열 미치다 고 렉 말 고 없다 고 끊기다 장난 게임 그래픽 사양 설정 하루 맞추다 고 글씨 깨지다 어서 안보 빠르다 시일 내 최적화 문제 해결하다 ㄴ지 궁금하다 이렇게 사양 높다 고 최적화 망하다 게임 내놓다 면 앱 플레이어 사용 막다 놓다 는지
# 리뷰 내용입니다:
# 게임 자체는 재밌는게 맞고 할것고 많고 지금 게임 나온지 얼마 안된지라 이벤트도 많고 점검 보상도 괜찮긴 한데 다른 사람들이 말하는 뽑기 확률 이런거 다 거두절미 하고 이 게임의 모든 장점 씹어먹을 만큼 진짜 최적화가 쓰레기에요 진짜 다른 평가에 최적화 잘 되어있다고 해놓은건 개구라.. 최적화 안되니까 발열 미쳤고 렉은 말할 것고 없고 끊김 장난 아님. (게임 그래픽 사양 설정에서 전부 하로 맞춰놓고 해도 그게 그거임 ㄹㅇ 글씨도 깨져서 안보임) 빠른 시일 내에 최적화 문제를 해결할건지 궁금하네요. 그리고 이렇게 사양 높고 최적화 개망한 게임 내놓을거면 앱플레이어 사용은 왜 막아놓으셨는지..?
#
# Review 9: 튜토리얼 하다 다가 지우다 게임 만들다 말다 그래픽 허접하다 특히 물 표현 너무 심하다 배경 캐릭터 전혀 어울리다 지 색감 고민 아예 알다 하다 오프닝 게임 배경 설명 없다 몰입도 없다 캐릭터 덩치 최대 들다 으니 캐릭터 이질감 생김 덩치 차이 배 정도 일반인 끼다 국산 모바일 게임 미래 보여주다 참담하다
# 리뷰 내용입니다:
# 튜토리얼 하다가 지움... 어찌 게임을 만들다 말았나? 그래픽 허접함, 특히 물 표현 너무 심함. 배경과 케릭터가 전혀 어울리지 않음. 색감 고민은 아예 안한것 같음. 오프닝에 게임 배경설명 없음, 몰입도 없음. 케릭덩치 최대치로 만드니까 다른 케릭들과 이질감 생김. 덩치차이 2배정도.. 일반인에 하승진 껴 있는것 같음. 국산 모바일게임의 현재와 미래를 보여주는것 같아 참담함
#
# Review 10: 게임 전반적 괜찮다 다고 생각 들다 하다 다가 탈퇴하다 하다 는데 탈퇴 하다 이유 이것다 모바일 게임 생각 들다 하다 개인 다르다 하다 이것다 모바일 게임 라 PC 게임 인 거 보이다 조그맣다 하다 폰 하다 딱히 덜 재미 고 몰입감 없다 고 폰 하다 너무 별로 그래픽 해상도 타격감 괜찮다 모바일 게임 딱히 라고 아무튼 안 하다 ㅎㅎ 기대다 하다 고 모바일 하다 무 별로
# 리뷰 내용입니다:
# 이 게임은 전반적으로 괜찮다고 생각이 듭니다 조금하다가 탈퇴하긴 했는데 .. 탈퇴를 한 이유 중 하나는 이게 모바일게임? 이라는 생각이 들기도 하더라구요 개인마다 다르기는 하겠지만 저는 이게 모바일게임이 아니라 PC게임인거 같아보이더라구요 조그마한 폰으로 하기에는 딱히 덜 재미가 있고 몰입감이 없고 폰으로 하기에는 너무 ... 별로더라구요 그래픽이나 해상도 타격감 등등 괜찮아요 다만 모바일게임은 딱히 아니라고 봐요 아무튼 저는 안하려고요 ㅎㅎ 기대는 하고 있었지만 모바일로 하기엔 너~~ 무 별로예요

# %% [markdown]
# ### 원본 리뷰만 출력되게 하기(검색)
# #### 긍정 빈도가 높은 키워드면 긍정 리뷰만
# #### 부정 빈도가 높은 키워드면 부정 리뷰만
# #### 긍부정 모두 포함되는 키워드면 함께 확인할 수 있게 긍부정 리뷰가 한번에 나타납니다

# %%
# 원본 리뷰를 출력하는 함수
def show_original_review(selected_review_num, original_data):
    """ 
    원본 데이터에서 선택한 리뷰 번호에 해당하는 리뷰 내용을 찾아 출력하는 함수
    
    :param selected_review_num: 선택한 리뷰의 번호
    :param original_data: 원본 데이터
    """
    selected_review = original_data[original_data['num'] == selected_review_num]['content'].values[0]
    print("리뷰 내용입니다:")
    print(selected_review)
    print()

def get_keyword_group(keyword, keyword_groups):
    """ 
    주어진 키워드에 해당하는 키워드 그룹을 반환하는 함수
    
    :param keyword: 검색할 키워드
    :param keyword_groups: 키워드 그룹 정보
    :return: 키워드에 해당하는 키워드 그룹
    """
    for group in keyword_groups:
        if keyword in group:
            return group
    return [keyword]

def get_top_reviews_by_keyword(keyword, data_source, keyword_groups):
    """ 
    주어진 키워드를 포함하는 리뷰 중에서 상위 10개의 리뷰를 반환하는 함수
    
    :param keyword: 검색할 키워드
    :param data_source: 검색할 데이터 (긍정 또는 부정 리뷰 데이터)
    :param keyword_groups: 키워드 그룹 정보
    :return: 상위 10개의 리뷰 내용 리스트
    """
    keyword_group = get_keyword_group(keyword, keyword_groups)  
    keyword_pattern = "|".join(keyword_group)
    keyword_reviews = data_source[data_source['content'].str.contains(keyword_pattern, regex=True)]
    sorted_reviews = keyword_reviews.sort_values(by='thumbsUpCount', ascending=False)
    return sorted_reviews.head(10)['content'].tolist()

def show_reviews_by_keyword(selected_keyword, data_positive, data_negative, keyword_groups):
    """ 
    선택한 키워드를 포함하는 긍정/부정 리뷰를 출력하는 함수
    
    :param selected_keyword: 검색어
    :param data_positive: 긍정 리뷰 데이터
    :param data_negative: 부정 리뷰 데이터
    :param keyword_groups: 키워드 그룹 정보
    """
    pos_reviews = get_top_reviews_by_keyword(selected_keyword, data_positive, keyword_groups)
    neg_reviews = get_top_reviews_by_keyword(selected_keyword, data_negative, keyword_groups)

    if not pos_reviews and not neg_reviews:
        print("해당 키워드를 포함하는 리뷰가 없습니다.")
        return

    if selected_keyword in top_5_keywords_neg.keys() and selected_keyword not in top_5_keywords_pos.keys():
        pos_reviews = []
    elif selected_keyword in top_5_keywords_pos.keys() and selected_keyword not in top_5_keywords_neg.keys():
        neg_reviews = []

    if pos_reviews:
        print("긍정 리뷰:")
        for review in pos_reviews:
            review_num = data_positive[data_positive['content'] == review]['num'].values[0]
            show_original_review(review_num, data)

    if neg_reviews:
        print("\n부정 리뷰:")
        for review in neg_reviews:
            review_num = data_negative[data_negative['content'] == review]['num'].values[0]
            show_original_review(review_num, data)

# 사용자로부터 검색할 키워드를 입력받는 부분
selected_keyword = input("검색어를 입력하세요: ").strip()
show_reviews_by_keyword(selected_keyword, data_positive, data_negative, keywords_grouped)
# Out:
# 검색어를 입력하세요: 타격감
# 긍정 리뷰:
# 리뷰 내용입니다:
# 뭔가 컷씬이나 qte같은 것들이 너무 뜬금없고 부자연스럽습니다. 총이나 칼을 사용하는데 타격감이 부드럽지도, 임팩트 있지도 않고 너무 스르륵 지나갑니다. 첫인상이 전혀 강하지않고 인디게임보다도 더 부족하다고 생각됩니다. 카카오게임즈는 개인적으로 응원하는 곳이라 좀 좋은 게임을 만들기를 기대합니다! 업데이트를 기대하겠습니다
#
# 리뷰 내용입니다:
# 다른 게임에 비해선 그래픽 완전 좋고, 타격감 좋고 다 좋네여~ 그런데..!! 단점은 딱 두가지있네요 발열이 심함 배터리 너무 빨리땀 이점만 고쳐주세요
#
# 리뷰 내용입니다:
# 게임이 너무 재미있어요. 타격감도 괜찮고 자사 돌리면서 창 기능을 사용해 드라마나 영화 웹툰 유튜브등 볼수있게 만들어주시고 내가 원하는 모바일게임이 이런느낌이라 좋습니다.
#
# 리뷰 내용입니다:
# 새롭고 넘넘 재밌네여 타격감도 있고 그래픽 끝내주고 다른 의상으로 교체하면 다른무기로도 할수 있고 나오는 인물들로 전환되어 진행도 되고 넘 재미나요~^^
#
# 리뷰 내용입니다:
# 근래 해본것중 타격감이 좋네요. 아직 초반이라그런지 게임 이해도가 낮아서그런지 좀 어려운듯한 느낌이 있음. 의상이 다양하고 예쁨.
#
# 리뷰 내용입니다:
# 재가 이 게임을 잠깐 플레이 했는데 그래픽도 최고 타격감 최고네요 스토리도 탄탄하고요
#
# 리뷰 내용입니다:
# 일단 시작한지는 얼마안됐지만 타격감이나 공속 보조무기등 엑션감이 좋네요...좀더 해봐야 하겠지만 아직은 만족하고 즐기고 있습니다...
#
# 리뷰 내용입니다:
# 그래픽 타격감 손쉬운 사냥 만족
#
# 리뷰 내용입니다:
# 기대했던것 만큼 잘만들어진것 같네요, 그래픽, 커마 는 요즘 출시 겜은 상향평준화 되어 언급할필요 없고, sf장르, 전투 액션 타격감,후판정 전투로 컨트롤 하는재미등 앞으로 잘운영해서 갓게임 되었으면 좋겠습니다.화이팅
#
# 리뷰 내용입니다:
# 그래픽 좋고, 타격감 좋고 근데 업그레이드나 기타시스템이 너무 복잡하고 어렵네요
